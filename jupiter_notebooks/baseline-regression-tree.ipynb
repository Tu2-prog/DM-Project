# %%
# Baseline Regression Tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

preprocessed_df = pd.read_csv("../DBtrainrides_info_message_cleanded.csv")
# Define the target and features for the regression tree
target_column = 'arrival_delay_m'  # Specify the target column

# Drop all rows with canceled == True
# Predicting arrival_delay_m
# Drop line, zip, arrival_change, departure_change, departure_delay_m, info, transformed_info_message, canceled
# Filter the DataFrame to only include the necessary columns

df_features = preprocessed_df.loc[preprocessed_df["canceled"] != True]
df_features = df_features.drop(["Unnamed: 0","line", "zip", "arrival_change", "departure_change", "departure_delay_m", "info", "transformed_info_message", "canceled"], axis=1)
df_target = preprocessed_df[target_column]
df_features
# Out:
# /tmp/ipykernel_57445/3668722008.py:7: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   preprocessed_df = pd.read_csv("../DBtrainrides_info_message_cleanded.csv")
#                      ID_Base  ID_Timestamp  stop_number  \
# 57       1573967790757085557    2407072312            1
# 58       1573967790757085557    2407072312            2
# 59       1573967790757085557    2407072312            3
# 60       1573967790757085557    2407072312            4
# 61       1573967790757085557    2407072312            5
# ...                      ...           ...          ...
# 2811475  6234297817509604666    2407112012            7
# 2811476  6234297817509604666    2407112012            8
# 2811477  6234297817509604666    2407112012            9
# 2811478  6234297817509604666    2407112012           10
# 2811479  6234297817509604666    2407112012           11
#
#          starting_station_IBNR               last_station       IBNR  \
# 57                     8000001  stolberg(rheinl)hbf gl.44        NaN
# 58                     8000001        eschweiler-st.jöris  8001917.0
# 59                     8000001         alsdorf poststraße  8000510.0
# 60                     8000001          alsdorf-mariadorf  8000527.0
# 61                     8000001        alsdorf-kellersberg  8000521.0
# ...                        ...                        ...        ...
# 2811475                8098360          stockstadt(rhein)  8005740.0
# 2811476                8098360                 biebesheim  8000951.0
# 2811477                8098360                  gernsheim  8002249.0
# 2811478                8098360              groß-rohrheim        NaN
# 2811479                8098360                     biblis  8000503.0
#
#              long        lat         arrival_plan       departure_plan  \
# 57            NaN        NaN                  NaN                  NaN
# 58            NaN        NaN                  NaN                  NaN
# 59            NaN        NaN                  NaN                  NaN
# 60            NaN        NaN                  NaN                  NaN
# 61            NaN        NaN                  NaN                  NaN
# ...           ...        ...                  ...                  ...
# 2811475       NaN        NaN                  NaN                  NaN
# 2811476  8.473978  49.781977  2024-07-11 20:45:00  2024-07-11 20:45:00
# 2811477       NaN        NaN                  NaN                  NaN
# 2811478       NaN        NaN                  NaN                  NaN
# 2811479  8.450413  49.688881  2024-07-11 20:56:00  2024-07-11 20:57:00
#
#          arrival_delay_m  info_present
# 57                   NaN         False
# 58                   NaN         False
# 59                   NaN         False
# 60                   NaN         False
# 61                   NaN         False
# ...                  ...           ...
# 2811475              NaN         False
# 2811476              0.0          True
# 2811477              NaN         False
# 2811478              NaN         False
# 2811479              0.0          True
#
# [2600125 rows x 12 columns]

# %%
df_features.groupby(["ID_Base"]).head(20)
# Out:
#                      ID_Base  ID_Timestamp  stop_number  \
# 57       1573967790757085557    2407072312            1
# 58       1573967790757085557    2407072312            2
# 59       1573967790757085557    2407072312            3
# 60       1573967790757085557    2407072312            4
# 61       1573967790757085557    2407072312            5
# ...                      ...           ...          ...
# 2811452  3075541027025221171    2407100511            3
# 2811453  3075541027025221171    2407100511            4
# 2811455  3075541027025221171    2407120511            2
# 2811456  3075541027025221171    2407120511            3
# 2811457  3075541027025221171    2407120511            4
#
#          starting_station_IBNR               last_station       IBNR  \
# 57                     8000001  stolberg(rheinl)hbf gl.44        NaN
# 58                     8000001        eschweiler-st.jöris  8001917.0
# 59                     8000001         alsdorf poststraße  8000510.0
# 60                     8000001          alsdorf-mariadorf  8000527.0
# 61                     8000001        alsdorf-kellersberg  8000521.0
# ...                        ...                        ...        ...
# 2811452                8098360           mannheim-waldhof  8003848.0
# 2811453                8098360                lampertheim  8003503.0
# 2811455                8098360          mannheim-käfertal  8003843.0
# 2811456                8098360           mannheim-waldhof  8003848.0
# 2811457                8098360                lampertheim  8003503.0
#
#              long        lat         arrival_plan       departure_plan  \
# 57            NaN        NaN                  NaN                  NaN
# 58            NaN        NaN                  NaN                  NaN
# 59            NaN        NaN                  NaN                  NaN
# 60            NaN        NaN                  NaN                  NaN
# 61            NaN        NaN                  NaN                  NaN
# ...           ...        ...                  ...                  ...
# 2811452  8.482603  49.525661  2024-07-10 05:19:00  2024-07-10 05:20:00
# 2811453  8.478489  49.598215  2024-07-10 05:28:00  2024-07-10 05:29:00
# 2811455       NaN        NaN                  NaN                  NaN
# 2811456  8.482603  49.525661  2024-07-12 05:19:00  2024-07-12 05:20:00
# 2811457  8.478489  49.598215  2024-07-12 05:28:00  2024-07-12 05:29:00
#
#          arrival_delay_m  info_present
# 57                   NaN         False
# 58                   NaN         False
# 59                   NaN         False
# 60                   NaN         False
# 61                   NaN         False
# ...                  ...           ...
# 2811452              0.0          True
# 2811453              0.0          True
# 2811455              NaN         False
# 2811456              0.0         False
# 2811457              0.0         False
#
# [708060 rows x 12 columns]

# %%
# Additional Preprocessing: Drop all Base ID's which have any NaN values except starting position
# Need  to interpolate/restore data

# Step 1: Identify the rows to drop
rows_to_drop = set()

# Step 2: Check each unique value in column A
for value in df_features['ID_Base'].unique():
    # Get rows that correspond to the current value
    rows_with_value = df_features[(df_features['ID_Base'] == value) & (df_features["stop_number"] != 1)]

    # Step 3: Check if any of these rows have NaN in any column other than A
    if rows_with_value.drop(columns='ID_Base').isnull().values.any():
        # If so, add the index of all rows with that value to rows_to_drop
        rows_to_drop.add(value)

# Step 4: Drop the identified rows
cleaned_df = df_features[df_features["ID_Base"].isin(rows_to_drop) == False]
cleaned_df
# Out:
#                      ID_Base  ID_Timestamp  stop_number  \
# 12190   -4723343422636309065    2407130634            2
# 12192   -4723343422636309065    2407140634            2
# 12227   -6627749385339055415    2407081034            2
# 12229   -6627749385339055415    2407091034            2
# 12231   -6627749385339055415    2407111034            2
# ...                      ...           ...          ...
# 2792541  1743114437240394004    2407120110            1
# 2792542   214163735824043521    2407120010            1
# 2792545  3104007004010608862    2407100231            2
# 2792547  3104007004010608862    2407110231            2
# 2810789  5444339805637406071    2407130500            2
#
#          starting_station_IBNR              last_station       IBNR  \
# 12190                  8000014                ravensburg  8004965.0
# 12192                  8000014                ravensburg  8004965.0
# 12227                  8000014                ravensburg  8004965.0
# 12229                  8000014                ravensburg  8004965.0
# 12231                  8000014                ravensburg  8004965.0
# ...                        ...                       ...        ...
# 2792541                8089131   berlin gesundbrunnen(s)  8089015.0
# 2792542                8089131   berlin gesundbrunnen(s)  8089015.0
# 2792545                8089131          berlin westhafen  8089116.0
# 2792547                8089131          berlin westhafen  8089116.0
# 2810789                8089474  berlin innsbrucker platz  8089106.0
#
#               long        lat         arrival_plan       departure_plan  \
# 12190     9.606100  47.784481  2024-07-13 06:45:00  2024-07-13 06:46:00
# 12192     9.606100  47.784481  2024-07-14 06:45:00  2024-07-14 06:46:00
# 12227     9.606100  47.784481  2024-07-08 10:45:00  2024-07-08 10:46:00
# 12229     9.606100  47.784481  2024-07-09 10:45:00  2024-07-09 10:46:00
# 12231     9.606100  47.784481  2024-07-11 10:45:00  2024-07-11 10:46:00
# ...            ...        ...                  ...                  ...
# 2792541        NaN        NaN                  NaN                  NaN
# 2792542        NaN        NaN                  NaN                  NaN
# 2792545  13.344253  52.536250  2024-07-10 02:32:00  2024-07-10 02:33:00
# 2792547  13.344253  52.536250  2024-07-11 02:32:00  2024-07-11 02:33:00
# 2810789  13.342197  52.478084  2024-07-13 05:01:00  2024-07-13 05:02:00
#
#          arrival_delay_m  info_present
# 12190                0.0         False
# 12192                0.0         False
# 12227                0.0          True
# 12229                0.0         False
# 12231                0.0         False
# ...                  ...           ...
# 2792541              NaN         False
# 2792542              NaN         False
# 2792545              0.0         False
# 2792547              0.0         False
# 2810789              0.0         False
#
# [92372 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
import numpy as np
# Step 2: Encode categorical data
# Encode 'last_station' using LabelEncoder
label_encoder = LabelEncoder()
cleaned_df['last_station_encoded'] = label_encoder.fit_transform(cleaned_df['last_station'])
#cleaned_df["ID_Base"] = label_encoder.fit_transform(cleaned_df["ID_Base"])

# Convert boolean 'info_present' to 0 and 1
cleaned_df['info_present'] = cleaned_df['info_present'].astype(int)

# Step 3: Convert datetime columns
cleaned_df['arrival_plan'] = pd.to_datetime(cleaned_df['arrival_plan'])
cleaned_df['departure_plan'] = pd.to_datetime(cleaned_df['departure_plan'])
cleaned_df['arrival_year'] = cleaned_df['arrival_plan'].dt.year
cleaned_df['arrival_month'] = cleaned_df['arrival_plan'].dt.month
cleaned_df['arrival_day'] = cleaned_df['arrival_plan'].dt.day
cleaned_df['arrival_hour'] = cleaned_df['arrival_plan'].dt.hour
cleaned_df['arrival_minute'] = cleaned_df['arrival_plan'].dt.minute

# Extract datetime components for departure_plan
cleaned_df['departure_year'] = cleaned_df['departure_plan'].dt.year
cleaned_df['departure_month'] = cleaned_df['departure_plan'].dt.month
cleaned_df['departure_day'] = cleaned_df['departure_plan'].dt.day
cleaned_df['departure_hour'] = cleaned_df['departure_plan'].dt.hour
cleaned_df['departure_minute'] = cleaned_df['departure_plan'].dt.minute

# Replace naN values in targets with 0 because they are all coming from the first stop of a train ride (others are filtered out above):
cleaned_df["arrival_delay_m"]= cleaned_df["arrival_delay_m"].fillna(0)

# Replace strange NaN in IBNR, long and lat
cleaned_df["IBNR"] = cleaned_df["IBNR"].fillna(0.0)
cleaned_df["long"] = cleaned_df["long"].fillna(0.0)
cleaned_df["lat"] = cleaned_df["lat"].fillna(0.0)

unique_base_ids = cleaned_df['ID_Base'].unique()

# Step 2: Shuffle and split unique Base_IDs into 80-20 split
np.random.seed(42)  # For reproducibility, if desired
shuffled_ids = np.random.permutation(unique_base_ids)
split_index = int(0.8 * len(shuffled_ids))

base_ids_80 = shuffled_ids[:split_index]  # 80% of Base_IDs
base_ids_20 = shuffled_ids[split_index:]  # 20% of Base_IDs

# Step 3: Split the dataframe based on the Base_ID sets
cleaned_train = cleaned_df[cleaned_df['ID_Base'].isin(base_ids_80)]
cleaned_test = cleaned_df[cleaned_df['ID_Base'].isin(base_ids_20)]

# Get Targets
cleaned_target_train = cleaned_train["arrival_delay_m"]
cleaned_features_train = cleaned_train.drop(columns=["arrival_delay_m","last_station","arrival_plan","departure_plan"])

cleaned_target_test = cleaned_test["arrival_delay_m"]
cleaned_features_test = cleaned_test.drop(columns=["arrival_delay_m","last_station","arrival_plan","departure_plan"])
cleaned_features_test
# Out:
# /tmp/ipykernel_57445/371814466.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['last_station_encoded'] = label_encoder.fit_transform(cleaned_df['last_station'])
# /tmp/ipykernel_57445/371814466.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['info_present'] = cleaned_df['info_present'].astype(int)
# /tmp/ipykernel_57445/371814466.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_plan'] = pd.to_datetime(cleaned_df['arrival_plan'])
# /tmp/ipykernel_57445/371814466.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_plan'] = pd.to_datetime(cleaned_df['departure_plan'])
# /tmp/ipykernel_57445/371814466.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_year'] = cleaned_df['arrival_plan'].dt.year
# /tmp/ipykernel_57445/371814466.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_month'] = cleaned_df['arrival_plan'].dt.month
# /tmp/ipykernel_57445/371814466.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_day'] = cleaned_df['arrival_plan'].dt.day
# /tmp/ipykernel_57445/371814466.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_hour'] = cleaned_df['arrival_plan'].dt.hour
# /tmp/ipykernel_57445/371814466.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['arrival_minute'] = cleaned_df['arrival_plan'].dt.minute
# /tmp/ipykernel_57445/371814466.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_year'] = cleaned_df['departure_plan'].dt.year
# /tmp/ipykernel_57445/371814466.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_month'] = cleaned_df['departure_plan'].dt.month
# /tmp/ipykernel_57445/371814466.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_day'] = cleaned_df['departure_plan'].dt.day
# /tmp/ipykernel_57445/371814466.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_hour'] = cleaned_df['departure_plan'].dt.hour
# /tmp/ipykernel_57445/371814466.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['departure_minute'] = cleaned_df['departure_plan'].dt.minute
# /tmp/ipykernel_57445/371814466.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["arrival_delay_m"]= cleaned_df["arrival_delay_m"].fillna(0)
# /tmp/ipykernel_57445/371814466.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["IBNR"] = cleaned_df["IBNR"].fillna(0.0)
# /tmp/ipykernel_57445/371814466.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["long"] = cleaned_df["long"].fillna(0.0)
# /tmp/ipykernel_57445/371814466.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df["lat"] = cleaned_df["lat"].fillna(0.0)
#                      ID_Base  ID_Timestamp  stop_number  \
# 12381    6426747683724885005    2407081824            2
# 12382    6426747683724885005    2407081824            3
# 12384    6426747683724885005    2407091824            2
# 12385    6426747683724885005    2407091824            3
# 18400   -8331387050508615038    2407040527            2
# ...                      ...           ...          ...
# 2792489 -2011326225307333304    2407102103            2
# 2792491 -2011326225307333304    2407112103            2
# 2792493 -2011326225307333304    2407122103            2
# 2792506 -6739302633902291034    2407142353            2
# 2792537 -8063888246690575093    2407112250            1
#
#          starting_station_IBNR       IBNR       long        lat  info_present  \
# 12381                  8000014  8000112.0   9.473900  47.653224             1
# 12382                  8000014  8004965.0   9.606100  47.784481             1
# 12384                  8000014  8000112.0   9.473900  47.653224             0
# 12385                  8000014  8004965.0   9.606100  47.784481             0
# 18400                  8000017  8004220.0   9.220068  49.188973             0
# ...                        ...        ...        ...        ...           ...
# 2792489                8089131  8089116.0  13.344253  52.536250             0
# 2792491                8089131  8089116.0  13.344253  52.536250             0
# 2792493                8089131  8089116.0  13.344253  52.536250             0
# 2792506                8089131  8089116.0  13.344253  52.536250             0
# 2792537                8089131  8089015.0   0.000000   0.000000             0
#
#          last_station_encoded  arrival_year  arrival_month  arrival_day  \
# 12381                     373        2024.0            7.0          8.0
# 12382                     834        2024.0            7.0          8.0
# 12384                     373        2024.0            7.0          9.0
# 12385                     834        2024.0            7.0          9.0
# 18400                     727        2024.0            7.0         11.0
# ...                       ...           ...            ...          ...
# 2792489                   107        2024.0            7.0         10.0
# 2792491                   107        2024.0            7.0         11.0
# 2792493                   107        2024.0            7.0         12.0
# 2792506                   107        2024.0            7.0         14.0
# 2792537                    78           NaN            NaN          NaN
#
#          arrival_hour  arrival_minute  departure_year  departure_month  \
# 12381            18.0            25.0          2024.0              7.0
# 12382            18.0            46.0          2024.0              7.0
# 12384            18.0            25.0          2024.0              7.0
# 12385            18.0            46.0          2024.0              7.0
# 18400             5.0            31.0          2024.0              7.0
# ...               ...             ...             ...              ...
# 2792489          21.0             4.0          2024.0              7.0
# 2792491          21.0             4.0          2024.0              7.0
# 2792493          21.0             4.0          2024.0              7.0
# 2792506          23.0            54.0          2024.0              7.0
# 2792537           NaN             NaN             NaN              NaN
#
#          departure_day  departure_hour  departure_minute
# 12381              8.0            18.0              35.0
# 12382              8.0            18.0              47.0
# 12384              9.0            18.0              35.0
# 12385              9.0            18.0              47.0
# 18400             11.0             5.0              31.0
# ...                ...             ...               ...
# 2792489           10.0            21.0               5.0
# 2792491           11.0            21.0               5.0
# 2792493           12.0            21.0               5.0
# 2792506           14.0            23.0              55.0
# 2792537            NaN             NaN               NaN
#
# [17287 rows x 19 columns]

# %%
"""# Initialize the regression tree model
regression_tree = DecisionTreeRegressor(max_depth=10, min_samples_leaf=5)

# Fit the model on the training data
regression_tree.fit(df_features_train, df_target_train)"""

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_features_train_scaled = scaler.fit_transform(cleaned_features_train)
df_features_test_scaled = scaler.transform(cleaned_features_test)
regression_tree = DecisionTreeRegressor(max_depth=10, min_samples_leaf=5, max_leaf_nodes=20)
# Train on scaled data
regression_tree.fit(df_features_train_scaled, cleaned_target_train)

# Predict on the test data
test_predictions = regression_tree.predict(cleaned_features_test)

# Calculate Mean Squared Error as a performance metric
mse = mean_squared_error(cleaned_target_test, test_predictions)
print("Mean Squared Error:", mse)

# Mean Squared Error: 14.935798910219793 ~ +/- 3.74min away from the actual delay
# Out:
# Mean Squared Error: 15.301193139589042
# /home/tu2/anaconda3/envs/data_mining/lib/python3.11/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Assuming 'regressor' is your trained DecisionTreeRegressor
plt.figure(figsize=(20, 10))  # Adjust size as needed for readability
plot_tree(regression_tree, feature_names=cleaned_features_train.columns, filled=True, rounded=True)
plt.show()

# %%
 # Access the tree structure
tree = regression_tree.tree_

for i in range(tree.node_count):
    print(f"Node {i}:")
    print(f"  Impurity (MSE) = {tree.impurity[i]}")
    print(f"  Samples = {tree.n_node_samples[i]}")
    print(f"  Value = {tree.value[i]}")
# Out:
# Node 0:
#   Impurity (MSE) = 17.52490459963004
#   Samples = 75085
#   Value = [[1.32914697]]
# Node 1:
#   Impurity (MSE) = 11.972637197515814
#   Samples = 62651
#   Value = [[0.94925859]]
# Node 2:
#   Impurity (MSE) = 16.445543170299672
#   Samples = 20699
#   Value = [[1.65887241]]
# Node 3:
#   Impurity (MSE) = 24.182926020144627
#   Samples = 8800
#   Value = [[2.31284091]]
# Node 4:
#   Impurity (MSE) = 16.22782368307579
#   Samples = 5507
#   Value = [[1.80315962]]
# Node 5:
#   Impurity (MSE) = 135.90999999999997
#   Samples = 20
#   Value = [[14.3]]
# Node 6:
#   Impurity (MSE) = 53.10204081632651
#   Samples = 7
#   Value = [[27.57142857]]
# Node 7:
#   Impurity (MSE) = 34.59171597633136
#   Samples = 13
#   Value = [[7.15384615]]
# Node 8:
#   Impurity (MSE) = 23.9375
#   Samples = 8
#   Value = [[5.25]]
# Node 9:
#   Impurity (MSE) = 36.56
#   Samples = 5
#   Value = [[10.2]]
# Node 10:
#   Impurity (MSE) = 15.220269697227259
#   Samples = 5487
#   Value = [[1.75760889]]
# Node 11:
#   Impurity (MSE) = 27.636975820404196
#   Samples = 1308
#   Value = [[2.87079511]]
# Node 12:
#   Impurity (MSE) = 25.608386004706954
#   Samples = 1282
#   Value = [[2.67784711]]
# Node 13:
#   Impurity (MSE) = 13.49156236483564
#   Samples = 544
#   Value = [[1.67463235]]
# Node 14:
#   Impurity (MSE) = 8.711633986928106
#   Samples = 510
#   Value = [[1.46666667]]
# Node 15:
#   Impurity (MSE) = 11.750284055043556
#   Samples = 89
#   Value = [[2.57303371]]
# Node 16:
#   Impurity (MSE) = 7.755790138850491
#   Samples = 421
#   Value = [[1.2327791]]
# Node 17:
#   Impurity (MSE) = 74.81055363321799
#   Samples = 34
#   Value = [[4.79411765]]
# Node 18:
#   Impurity (MSE) = 180.81
#   Samples = 10
#   Value = [[9.7]]
# Node 19:
#   Impurity (MSE) = 16.4375
#   Samples = 24
#   Value = [[2.75]]
# Node 20:
#   Impurity (MSE) = 33.251298095636784
#   Samples = 738
#   Value = [[3.41734417]]
# Node 21:
#   Impurity (MSE) = 24.96035002570776
#   Samples = 707
#   Value = [[3.16407355]]
# Node 22:
#   Impurity (MSE) = 13.102081811541272
#   Samples = 148
#   Value = [[1.66216216]]
# Node 23:
#   Impurity (MSE) = 27.34458095052179
#   Samples = 559
#   Value = [[3.56171735]]
# Node 24:
#   Impurity (MSE) = 187.51092611862646
#   Samples = 31
#   Value = [[9.19354839]]
# Node 25:
#   Impurity (MSE) = 5.52888888888889
#   Samples = 15
#   Value = [[1.93333333]]
# Node 26:
#   Impurity (MSE) = 262.375
#   Samples = 16
#   Value = [[16.]]
# Node 27:
#   Impurity (MSE) = 35.31360946745559
#   Samples = 26
#   Value = [[12.38461538]]
# Node 28:
#   Impurity (MSE) = 22.45674740484428
#   Samples = 17
#   Value = [[10.88235294]]
# Node 29:
#   Impurity (MSE) = 13.599999999999994
#   Samples = 5
#   Value = [[8.]]
# Node 30:
#   Impurity (MSE) = 21.243055555555543
#   Samples = 12
#   Value = [[12.08333333]]
# Node 31:
#   Impurity (MSE) = 6.81632653061223
#   Samples = 7
#   Value = [[14.42857143]]
# Node 32:
#   Impurity (MSE) = 22.959999999999994
#   Samples = 5
#   Value = [[8.8]]
# Node 33:
#   Impurity (MSE) = 47.28395061728398
#   Samples = 9
#   Value = [[15.22222222]]
# Node 34:
#   Impurity (MSE) = 10.824667899027494
#   Samples = 4179
#   Value = [[1.4091888]]
# Node 35:
#   Impurity (MSE) = 14.24688392507731
#   Samples = 1805
#   Value = [[1.98559557]]
# Node 36:
#   Impurity (MSE) = 9.077660728779529
#   Samples = 1530
#   Value = [[1.70718954]]
# Node 37:
#   Impurity (MSE) = 2.035530129097821
#   Samples = 326
#   Value = [[0.57668712]]
# Node 38:
#   Impurity (MSE) = 3.1936
#   Samples = 175
#   Value = [[0.92]]
# Node 39:
#   Impurity (MSE) = 0.3984912942414806
#   Samples = 151
#   Value = [[0.17880795]]
# Node 40:
#   Impurity (MSE) = 10.54467389984658
#   Samples = 1204
#   Value = [[2.01328904]]
# Node 41:
#   Impurity (MSE) = 9.280424149338375
#   Samples = 920
#   Value = [[1.70326087]]
# Node 42:
#   Impurity (MSE) = 13.320112576869667
#   Samples = 284
#   Value = [[3.01760563]]
# Node 43:
#   Impurity (MSE) = 40.176079338842975
#   Samples = 275
#   Value = [[3.53454545]]
# Node 44:
#   Impurity (MSE) = 25.625346260387808
#   Samples = 152
#   Value = [[5.42105263]]
# Node 45:
#   Impurity (MSE) = 11.992028061224488
#   Samples = 56
#   Value = [[2.41071429]]
# Node 46:
#   Impurity (MSE) = 25.208224826388893
#   Samples = 96
#   Value = [[7.17708333]]
# Node 47:
#   Impurity (MSE) = 48.324542269812945
#   Samples = 123
#   Value = [[1.20325203]]
# Node 48:
#   Impurity (MSE) = 1.4630672760123287
#   Samples = 97
#   Value = [[0.71134021]]
# Node 49:
#   Impurity (MSE) = 218.88313609467457
#   Samples = 26
#   Value = [[3.03846154]]
# Node 50:
#   Impurity (MSE) = 7.778009487788588
#   Samples = 2374
#   Value = [[0.97093513]]
# Node 51:
#   Impurity (MSE) = 6.391803002192612
#   Samples = 154
#   Value = [[2.8961039]]
# Node 52:
#   Impurity (MSE) = 1.2341269841269842
#   Samples = 42
#   Value = [[1.83333333]]
# Node 53:
#   Impurity (MSE) = 2.8000000000000007
#   Samples = 5
#   Value = [[3.]]
# Node 54:
#   Impurity (MSE) = 0.8137326515704895
#   Samples = 37
#   Value = [[1.67567568]]
# Node 55:
#   Impurity (MSE) = 7.7435427295918355
#   Samples = 112
#   Value = [[3.29464286]]
# Node 56:
#   Impurity (MSE) = 24.639999999999986
#   Samples = 5
#   Value = [[6.4]]
# Node 57:
#   Impurity (MSE) = 6.482312865752467
#   Samples = 107
#   Value = [[3.14953271]]
# Node 58:
#   Impurity (MSE) = 7.599232813894975
#   Samples = 2220
#   Value = [[0.83738739]]
# Node 59:
#   Impurity (MSE) = 14.300329287190083
#   Samples = 176
#   Value = [[2.15340909]]
# Node 60:
#   Impurity (MSE) = 24.80555555555555
#   Samples = 36
#   Value = [[4.16666667]]
# Node 61:
#   Impurity (MSE) = 10.288724489795918
#   Samples = 140
#   Value = [[1.63571429]]
# Node 62:
#   Impurity (MSE) = 6.86026210071193
#   Samples = 2044
#   Value = [[0.72407045]]
# Node 63:
#   Impurity (MSE) = 5.589711976311127
#   Samples = 1803
#   Value = [[0.63006101]]
# Node 64:
#   Impurity (MSE) = 15.804893166439973
#   Samples = 241
#   Value = [[1.42738589]]
# Node 65:
#   Impurity (MSE) = 36.32557904485759
#   Samples = 3293
#   Value = [[3.16519891]]
# Node 66:
#   Impurity (MSE) = 16.635908854054527
#   Samples = 1591
#   Value = [[2.28724073]]
# Node 67:
#   Impurity (MSE) = 317.13888888888886
#   Samples = 6
#   Value = [[12.83333333]]
# Node 68:
#   Impurity (MSE) = 15.075742021514792
#   Samples = 1585
#   Value = [[2.24731861]]
# Node 69:
#   Impurity (MSE) = 22.25438376415098
#   Samples = 509
#   Value = [[3.10412574]]
# Node 70:
#   Impurity (MSE) = 12.606872046944064
#   Samples = 324
#   Value = [[2.46604938]]
# Node 71:
#   Impurity (MSE) = 92.984375
#   Samples = 8
#   Value = [[8.375]]
# Node 72:
#   Impurity (MSE) = 9.665678577151098
#   Samples = 316
#   Value = [[2.3164557]]
# Node 73:
#   Impurity (MSE) = 4.156883492982846
#   Samples = 134
#   Value = [[1.44029851]]
# Node 74:
#   Impurity (MSE) = 12.740278951817412
#   Samples = 182
#   Value = [[2.96153846]]
# Node 75:
#   Impurity (MSE) = 37.188721694667635
#   Samples = 185
#   Value = [[4.22162162]]
# Node 76:
#   Impurity (MSE) = 4.154857560262966
#   Samples = 37
#   Value = [[1.2972973]]
# Node 77:
#   Impurity (MSE) = 0.45422116527942924
#   Samples = 29
#   Value = [[0.55172414]]
# Node 78:
#   Impurity (MSE) = 8.25
#   Samples = 8
#   Value = [[4.]]
# Node 79:
#   Impurity (MSE) = 42.77478999269539
#   Samples = 148
#   Value = [[4.9527027]]
# Node 80:
#   Impurity (MSE) = 56.669607225372815
#   Samples = 69
#   Value = [[6.28985507]]
# Node 81:
#   Impurity (MSE) = 27.713186989264543
#   Samples = 79
#   Value = [[3.78481013]]
# Node 82:
#   Impurity (MSE) = 11.168346899572974
#   Samples = 1076
#   Value = [[1.84200743]]
# Node 83:
#   Impurity (MSE) = 22.388008781298204
#   Samples = 318
#   Value = [[2.51886792]]
# Node 84:
#   Impurity (MSE) = 12.940083234244945
#   Samples = 290
#   Value = [[1.85172414]]
# Node 85:
#   Impurity (MSE) = 20.168685121107266
#   Samples = 136
#   Value = [[2.58823529]]
# Node 86:
#   Impurity (MSE) = 5.654284027660651
#   Samples = 154
#   Value = [[1.2012987]]
# Node 87:
#   Impurity (MSE) = 67.8877551020408
#   Samples = 28
#   Value = [[9.42857143]]
# Node 88:
#   Impurity (MSE) = 36.59171597633133
#   Samples = 13
#   Value = [[16.84615385]]
# Node 89:
#   Impurity (MSE) = 6.0
#   Samples = 15
#   Value = [[3.]]
# Node 90:
#   Impurity (MSE) = 6.188582995105855
#   Samples = 758
#   Value = [[1.55804749]]
# Node 91:
#   Impurity (MSE) = 7.594007882073726
#   Samples = 567
#   Value = [[1.7654321]]
# Node 92:
#   Impurity (MSE) = 9.328555976203353
#   Samples = 344
#   Value = [[2.09302326]]
# Node 93:
#   Impurity (MSE) = 4.497375776709767
#   Samples = 223
#   Value = [[1.26008969]]
# Node 94:
#   Impurity (MSE) = 1.5097722101916067
#   Samples = 191
#   Value = [[0.94240838]]
# Node 95:
#   Impurity (MSE) = 0.6315972222222224
#   Samples = 120
#   Value = [[0.54166667]]
# Node 96:
#   Impurity (MSE) = 2.2638365403689744
#   Samples = 71
#   Value = [[1.61971831]]
# Node 97:
#   Impurity (MSE) = 53.33705145394718
#   Samples = 1702
#   Value = [[3.98589894]]
# Node 98:
#   Impurity (MSE) = 6.709393592584477
#   Samples = 351
#   Value = [[2.002849]]
# Node 99:
#   Impurity (MSE) = 11.057633117882427
#   Samples = 114
#   Value = [[3.06140351]]
# Node 100:
#   Impurity (MSE) = 14.080357142857146
#   Samples = 56
#   Value = [[4.25]]
# Node 101:
#   Impurity (MSE) = 29.35204081632653
#   Samples = 14
#   Value = [[5.92857143]]
# Node 102:
#   Impurity (MSE) = 57.13888888888889
#   Samples = 6
#   Value = [[7.83333333]]
# Node 103:
#   Impurity (MSE) = 3.75
#   Samples = 8
#   Value = [[4.5]]
# Node 104:
#   Impurity (MSE) = 7.737528344671201
#   Samples = 42
#   Value = [[3.69047619]]
# Node 105:
#   Impurity (MSE) = 2.2474999999999987
#   Samples = 20
#   Value = [[2.45]]
# Node 106:
#   Impurity (MSE) = 10.057851239669422
#   Samples = 22
#   Value = [[4.81818182]]
# Node 107:
#   Impurity (MSE) = 5.458085612366231
#   Samples = 58
#   Value = [[1.9137931]]
# Node 108:
#   Impurity (MSE) = 9.07266435986159
#   Samples = 17
#   Value = [[3.47058824]]
# Node 109:
#   Impurity (MSE) = 2.0
#   Samples = 6
#   Value = [[1.]]
# Node 110:
#   Impurity (MSE) = 7.785123966942148
#   Samples = 11
#   Value = [[4.81818182]]
# Node 111:
#   Impurity (MSE) = 2.5377751338489
#   Samples = 41
#   Value = [[1.26829268]]
# Node 112:
#   Impurity (MSE) = 0.33136094674556216
#   Samples = 13
#   Value = [[0.23076923]]
# Node 113:
#   Impurity (MSE) = 2.8303571428571432
#   Samples = 28
#   Value = [[1.75]]
# Node 114:
#   Impurity (MSE) = 3.819580195481494
#   Samples = 237
#   Value = [[1.49367089]]
# Node 115:
#   Impurity (MSE) = 6.014875283446712
#   Samples = 105
#   Value = [[2.15238095]]
# Node 116:
#   Impurity (MSE) = 9.122085048010973
#   Samples = 54
#   Value = [[2.62962963]]
# Node 117:
#   Impurity (MSE) = 3.5514574657941695
#   Samples = 41
#   Value = [[2.09756098]]
# Node 118:
#   Impurity (MSE) = 22.982248520710062
#   Samples = 13
#   Value = [[4.30769231]]
# Node 119:
#   Impurity (MSE) = 2.2283737024221457
#   Samples = 51
#   Value = [[1.64705882]]
# Node 120:
#   Impurity (MSE) = 2.053877551020408
#   Samples = 35
#   Value = [[1.94285714]]
# Node 121:
#   Impurity (MSE) = 2.0
#   Samples = 16
#   Value = [[1.]]
# Node 122:
#   Impurity (MSE) = 1.4536271808999082
#   Samples = 132
#   Value = [[0.96969697]]
# Node 123:
#   Impurity (MSE) = 1.7075999999999993
#   Samples = 50
#   Value = [[1.82]]
# Node 124:
#   Impurity (MSE) = 1.734375
#   Samples = 16
#   Value = [[2.875]]
# Node 125:
#   Impurity (MSE) = 0.9247404844290656
#   Samples = 34
#   Value = [[1.32352941]]
# Node 126:
#   Impurity (MSE) = 0.5890838786436645
#   Samples = 82
#   Value = [[0.45121951]]
# Node 127:
#   Impurity (MSE) = 0.1206525084641428
#   Samples = 57
#   Value = [[0.14035088]]
# Node 128:
#   Impurity (MSE) = 0.9343999999999999
#   Samples = 25
#   Value = [[1.16]]
# Node 129:
#   Impurity (MSE) = 64.16413644305477
#   Samples = 1351
#   Value = [[4.50111029]]
# Node 130:
#   Impurity (MSE) = 79.18416350136496
#   Samples = 893
#   Value = [[5.34378499]]
# Node 131:
#   Impurity (MSE) = 72.99810095951518
#   Samples = 872
#   Value = [[5.04357798]]
# Node 132:
#   Impurity (MSE) = 62.75603370264562
#   Samples = 839
#   Value = [[4.73778308]]
# Node 133:
#   Impurity (MSE) = 82.44261822376009
#   Samples = 306
#   Value = [[6.2254902]]
# Node 134:
#   Impurity (MSE) = 49.453636008433975
#   Samples = 533
#   Value = [[3.8836773]]
# Node 135:
#   Impurity (MSE) = 270.5730027548209
#   Samples = 33
#   Value = [[12.81818182]]
# Node 136:
#   Impurity (MSE) = 41.39792387543252
#   Samples = 17
#   Value = [[5.88235294]]
# Node 137:
#   Impurity (MSE) = 408.65234375
#   Samples = 16
#   Value = [[20.1875]]
# Node 138:
#   Impurity (MSE) = 176.9160997732426
#   Samples = 21
#   Value = [[17.80952381]]
# Node 139:
#   Impurity (MSE) = 183.7066666666666
#   Samples = 15
#   Value = [[21.6]]
# Node 140:
#   Impurity (MSE) = 104.40816326530609
#   Samples = 7
#   Value = [[15.85714286]]
# Node 141:
#   Impurity (MSE) = 198.984375
#   Samples = 8
#   Value = [[26.625]]
# Node 142:
#   Impurity (MSE) = 34.222222222222214
#   Samples = 6
#   Value = [[8.33333333]]
# Node 143:
#   Impurity (MSE) = 30.794268797315077
#   Samples = 458
#   Value = [[2.8580786]]
# Node 144:
#   Impurity (MSE) = 17.358654268186875
#   Samples = 313
#   Value = [[2.28115016]]
# Node 145:
#   Impurity (MSE) = 18.388298128858025
#   Samples = 288
#   Value = [[2.47569444]]
# Node 146:
#   Impurity (MSE) = 19.504820220719118
#   Samples = 265
#   Value = [[2.66792453]]
# Node 147:
#   Impurity (MSE) = 0.19281663516068054
#   Samples = 23
#   Value = [[0.26086957]]
# Node 148:
#   Impurity (MSE) = 0.038400000000000004
#   Samples = 25
#   Value = [[0.04]]
# Node 149:
#   Impurity (MSE) = 0.0
#   Samples = 20
#   Value = [[0.]]
# Node 150:
#   Impurity (MSE) = 0.16
#   Samples = 5
#   Value = [[0.2]]
# Node 151:
#   Impurity (MSE) = 57.52722948870392
#   Samples = 145
#   Value = [[4.10344828]]
# Node 152:
#   Impurity (MSE) = 44.15511916554979
#   Samples = 131
#   Value = [[3.44274809]]
# Node 153:
#   Impurity (MSE) = 55.015610651974285
#   Samples = 99
#   Value = [[4.21212121]]
# Node 154:
#   Impurity (MSE) = 3.05859375
#   Samples = 32
#   Value = [[1.0625]]
# Node 155:
#   Impurity (MSE) = 140.34693877551018
#   Samples = 14
#   Value = [[10.28571429]]
# Node 156:
#   Impurity (MSE) = 106.75
#   Samples = 8
#   Value = [[18.]]
# Node 157:
#   Impurity (MSE) = 0.0
#   Samples = 6
#   Value = [[0.]]
# Node 158:
#   Impurity (MSE) = 10.173094904919441
#   Samples = 11899
#   Value = [[1.17522481]]
# Node 159:
#   Impurity (MSE) = 20.286208909274805
#   Samples = 3386
#   Value = [[1.92144123]]
# Node 160:
#   Impurity (MSE) = 18.972005605998525
#   Samples = 3095
#   Value = [[1.75508885]]
# Node 161:
#   Impurity (MSE) = 18.87739540849203
#   Samples = 2666
#   Value = [[1.55926482]]
# Node 162:
#   Impurity (MSE) = 19.905106707317074
#   Samples = 328
#   Value = [[2.625]]
# Node 163:
#   Impurity (MSE) = 9.310504030200999
#   Samples = 198
#   Value = [[1.6010101]]
# Node 164:
#   Impurity (MSE) = 0.8289473684210527
#   Samples = 38
#   Value = [[0.5]]
# Node 165:
#   Impurity (MSE) = 0.2646484375
#   Samples = 32
#   Value = [[0.28125]]
# Node 166:
#   Impurity (MSE) = 2.222222222222222
#   Samples = 6
#   Value = [[1.66666667]]
# Node 167:
#   Impurity (MSE) = 10.96859375
#   Samples = 160
#   Value = [[1.8625]]
# Node 168:
#   Impurity (MSE) = 14.867499344920954
#   Samples = 107
#   Value = [[2.30841121]]
# Node 169:
#   Impurity (MSE) = 1.885368458526166
#   Samples = 53
#   Value = [[0.96226415]]
# Node 170:
#   Impurity (MSE) = 32.01207100591716
#   Samples = 130
#   Value = [[4.18461538]]
# Node 171:
#   Impurity (MSE) = 37.67313019390582
#   Samples = 57
#   Value = [[5.89473684]]
# Node 172:
#   Impurity (MSE) = 3.4097222222222214
#   Samples = 12
#   Value = [[1.91666667]]
# Node 173:
#   Impurity (MSE) = 41.464691358024695
#   Samples = 45
#   Value = [[6.95555556]]
# Node 174:
#   Impurity (MSE) = 23.525239256896228
#   Samples = 73
#   Value = [[2.84931507]]
# Node 175:
#   Impurity (MSE) = 66.06228373702422
#   Samples = 17
#   Value = [[5.76470588]]
# Node 176:
#   Impurity (MSE) = 7.248724489795919
#   Samples = 56
#   Value = [[1.96428571]]
# Node 177:
#   Impurity (MSE) = 18.551521666431285
#   Samples = 2338
#   Value = [[1.40975192]]
# Node 178:
#   Impurity (MSE) = 0.0
#   Samples = 129
#   Value = [[0.]]
# Node 179:
#   Impurity (MSE) = 19.512046791583305
#   Samples = 2209
#   Value = [[1.49207786]]
# Node 180:
#   Impurity (MSE) = 81.3361443751054
#   Samples = 154
#   Value = [[2.67532468]]
# Node 181:
#   Impurity (MSE) = 5.600176047728496
#   Samples = 143
#   Value = [[1.03496503]]
# Node 182:
#   Impurity (MSE) = 576.1818181818182
#   Samples = 11
#   Value = [[24.]]
# Node 183:
#   Impurity (MSE) = 14.766217107405236
#   Samples = 2055
#   Value = [[1.40340633]]
# Node 184:
#   Impurity (MSE) = 18.83411600902475
#   Samples = 1263
#   Value = [[1.65479018]]
# Node 185:
#   Impurity (MSE) = 8.017670390776452
#   Samples = 792
#   Value = [[1.00252525]]
# Node 186:
#   Impurity (MSE) = 17.840709407142974
#   Samples = 429
#   Value = [[2.97202797]]
# Node 187:
#   Impurity (MSE) = 23.463438040657444
#   Samples = 272
#   Value = [[3.70955882]]
# Node 188:
#   Impurity (MSE) = 10.007633136094674
#   Samples = 130
#   Value = [[2.60769231]]
# Node 189:
#   Impurity (MSE) = 4.6198224852071
#   Samples = 52
#   Value = [[1.73076923]]
# Node 190:
#   Impurity (MSE) = 5.626666666666666
#   Samples = 30
#   Value = [[2.2]]
# Node 191:
#   Impurity (MSE) = 2.537190082644628
#   Samples = 22
#   Value = [[1.09090909]]
# Node 192:
#   Impurity (MSE) = 12.74506903353057
#   Samples = 78
#   Value = [[3.19230769]]
# Node 193:
#   Impurity (MSE) = 13.369600000000002
#   Samples = 25
#   Value = [[4.52]]
# Node 194:
#   Impurity (MSE) = 11.226771092915628
#   Samples = 53
#   Value = [[2.56603774]]
# Node 195:
#   Impurity (MSE) = 33.65304503074786
#   Samples = 142
#   Value = [[4.71830986]]
# Node 196:
#   Impurity (MSE) = 105.15234375
#   Samples = 16
#   Value = [[10.1875]]
# Node 197:
#   Impurity (MSE) = 197.47222222222223
#   Samples = 6
#   Value = [[15.83333333]]
# Node 198:
#   Impurity (MSE) = 19.16000000000001
#   Samples = 10
#   Value = [[6.8]]
# Node 199:
#   Impurity (MSE) = 20.293083900226755
#   Samples = 126
#   Value = [[4.02380952]]
# Node 200:
#   Impurity (MSE) = 8.522491349480969
#   Samples = 34
#   Value = [[2.35294118]]
# Node 201:
#   Impurity (MSE) = 23.230033081285445
#   Samples = 92
#   Value = [[4.64130435]]
# Node 202:
#   Impurity (MSE) = 5.524362043084912
#   Samples = 157
#   Value = [[1.69426752]]
# Node 203:
#   Impurity (MSE) = 5.737654320987654
#   Samples = 72
#   Value = [[1.11111111]]
# Node 204:
#   Impurity (MSE) = 2.365337491646246
#   Samples = 67
#   Value = [[0.80597015]]
# Node 205:
#   Impurity (MSE) = 2.7087603305785124
#   Samples = 55
#   Value = [[0.98181818]]
# Node 206:
#   Impurity (MSE) = 0.0
#   Samples = 12
#   Value = [[0.]]
# Node 207:
#   Impurity (MSE) = 32.959999999999994
#   Samples = 5
#   Value = [[5.2]]
# Node 208:
#   Impurity (MSE) = 4.811626297577853
#   Samples = 85
#   Value = [[2.18823529]]
# Node 209:
#   Impurity (MSE) = 6.842469135802467
#   Samples = 45
#   Value = [[2.95555556]]
# Node 210:
#   Impurity (MSE) = 4.558367346938775
#   Samples = 35
#   Value = [[2.31428571]]
# Node 211:
#   Impurity (MSE) = 8.359999999999996
#   Samples = 10
#   Value = [[5.2]]
# Node 212:
#   Impurity (MSE) = 1.119375
#   Samples = 40
#   Value = [[1.325]]
# Node 213:
#   Impurity (MSE) = 0.43359375
#   Samples = 16
#   Value = [[0.9375]]
# Node 214:
#   Impurity (MSE) = 1.4097222222222223
#   Samples = 24
#   Value = [[1.58333333]]
# Node 215:
#   Impurity (MSE) = 30.8390548056825
#   Samples = 291
#   Value = [[3.69072165]]
# Node 216:
#   Impurity (MSE) = 48.99784549092028
#   Samples = 114
#   Value = [[5.14035088]]
# Node 217:
#   Impurity (MSE) = 20.85459533607682
#   Samples = 54
#   Value = [[3.18518519]]
# Node 218:
#   Impurity (MSE) = 0.20408163265306123
#   Samples = 7
#   Value = [[0.28571429]]
# Node 219:
#   Impurity (MSE) = 22.49162516976007
#   Samples = 47
#   Value = [[3.61702128]]
# Node 220:
#   Impurity (MSE) = 56.96
#   Samples = 5
#   Value = [[7.8]]
# Node 221:
#   Impurity (MSE) = 16.057256235827666
#   Samples = 42
#   Value = [[3.11904762]]
# Node 222:
#   Impurity (MSE) = 8.247658688865766
#   Samples = 31
#   Value = [[2.5483871]]
# Node 223:
#   Impurity (MSE) = 34.56198347107437
#   Samples = 11
#   Value = [[4.72727273]]
# Node 224:
#   Impurity (MSE) = 67.78999999999999
#   Samples = 60
#   Value = [[6.9]]
# Node 225:
#   Impurity (MSE) = 8.5
#   Samples = 12
#   Value = [[3.]]
# Node 226:
#   Impurity (MSE) = 8.888888888888886
#   Samples = 6
#   Value = [[4.66666667]]
# Node 227:
#   Impurity (MSE) = 2.5555555555555554
#   Samples = 6
#   Value = [[1.33333333]]
# Node 228:
#   Impurity (MSE) = 77.859375
#   Samples = 48
#   Value = [[7.875]]
# Node 229:
#   Impurity (MSE) = 11.2
#   Samples = 5
#   Value = [[3.]]
# Node 230:
#   Impurity (MSE) = 82.52568956192535
#   Samples = 43
#   Value = [[8.44186047]]
# Node 231:
#   Impurity (MSE) = 159.76
#   Samples = 5
#   Value = [[17.8]]
# Node 232:
#   Impurity (MSE) = 59.32409972299169
#   Samples = 38
#   Value = [[7.21052632]]
# Node 233:
#   Impurity (MSE) = 16.9183823294711
#   Samples = 177
#   Value = [[2.75706215]]
# Node 234:
#   Impurity (MSE) = 21.262855501292734
#   Samples = 118
#   Value = [[3.30508475]]
# Node 235:
#   Impurity (MSE) = 5.759809750297265
#   Samples = 29
#   Value = [[1.5862069]]
# Node 236:
#   Impurity (MSE) = 1.4556213017751476
#   Samples = 13
#   Value = [[0.92307692]]
# Node 237:
#   Impurity (MSE) = 2.6399999999999997
#   Samples = 5
#   Value = [[1.6]]
# Node 238:
#   Impurity (MSE) = 0.25
#   Samples = 8
#   Value = [[0.5]]
# Node 239:
#   Impurity (MSE) = 8.609375
#   Samples = 16
#   Value = [[2.125]]
# Node 240:
#   Impurity (MSE) = 14.109375
#   Samples = 8
#   Value = [[2.875]]
# Node 241:
#   Impurity (MSE) = 1.984375
#   Samples = 8
#   Value = [[1.375]]
# Node 242:
#   Impurity (MSE) = 25.038000252493372
#   Samples = 89
#   Value = [[3.86516854]]
# Node 243:
#   Impurity (MSE) = 28.42109213736161
#   Samples = 73
#   Value = [[4.35616438]]
# Node 244:
#   Impurity (MSE) = 19.15912208504801
#   Samples = 54
#   Value = [[3.62962963]]
# Node 245:
#   Impurity (MSE) = 48.98060941828255
#   Samples = 19
#   Value = [[6.42105263]]
# Node 246:
#   Impurity (MSE) = 3.484375
#   Samples = 16
#   Value = [[1.625]]
# Node 247:
#   Impurity (MSE) = 1.1020408163265307
#   Samples = 7
#   Value = [[0.57142857]]
# Node 248:
#   Impurity (MSE) = 3.802469135802469
#   Samples = 9
#   Value = [[2.44444444]]
# Node 249:
#   Impurity (MSE) = 6.427463372594083
#   Samples = 59
#   Value = [[1.66101695]]
# Node 250:
#   Impurity (MSE) = 7.034217608612073
#   Samples = 51
#   Value = [[1.84313725]]
# Node 251:
#   Impurity (MSE) = 3.876033057851239
#   Samples = 22
#   Value = [[1.18181818]]
# Node 252:
#   Impurity (MSE) = 11.760000000000002
#   Samples = 5
#   Value = [[2.2]]
# Node 253:
#   Impurity (MSE) = 1.1626297577854672
#   Samples = 17
#   Value = [[0.88235294]]
# Node 254:
#   Impurity (MSE) = 8.846611177170036
#   Samples = 29
#   Value = [[2.34482759]]
# Node 255:
#   Impurity (MSE) = 4.555555555555556
#   Samples = 24
#   Value = [[1.83333333]]
# Node 256:
#   Impurity (MSE) = 22.160000000000004
#   Samples = 5
#   Value = [[4.8]]
# Node 257:
#   Impurity (MSE) = 1.0
#   Samples = 8
#   Value = [[0.5]]
# Node 258:
#   Impurity (MSE) = 5.841086101426072
#   Samples = 8513
#   Value = [[0.87842124]]
# Node 259:
#   Impurity (MSE) = 20.63752973615917
#   Samples = 272
#   Value = [[3.14338235]]
# Node 260:
#   Impurity (MSE) = 2.7171597633136093
#   Samples = 65
#   Value = [[0.92307692]]
# Node 261:
#   Impurity (MSE) = 0.691358024691358
#   Samples = 45
#   Value = [[0.44444444]]
# Node 262:
#   Impurity (MSE) = 0.19066403681788296
#   Samples = 39
#   Value = [[0.25641026]]
# Node 263:
#   Impurity (MSE) = 0.2222222222222222
#   Samples = 15
#   Value = [[0.66666667]]
# Node 264:
#   Impurity (MSE) = 0.15999999999999992
#   Samples = 10
#   Value = [[0.8]]
# Node 265:
#   Impurity (MSE) = 0.24
#   Samples = 5
#   Value = [[0.4]]
# Node 266:
#   Impurity (MSE) = 0.0
#   Samples = 24
#   Value = [[0.]]
# Node 267:
#   Impurity (MSE) = 2.222222222222222
#   Samples = 6
#   Value = [[1.66666667]]
# Node 268:
#   Impurity (MSE) = 5.6
#   Samples = 20
#   Value = [[2.]]
# Node 269:
#   Impurity (MSE) = 7.610000000000001
#   Samples = 10
#   Value = [[3.3]]
# Node 270:
#   Impurity (MSE) = 5.440000000000005
#   Samples = 5
#   Value = [[4.6]]
# Node 271:
#   Impurity (MSE) = 6.4
#   Samples = 5
#   Value = [[2.]]
# Node 272:
#   Impurity (MSE) = 0.21000000000000002
#   Samples = 10
#   Value = [[0.7]]
# Node 273:
#   Impurity (MSE) = 0.24
#   Samples = 5
#   Value = [[0.6]]
# Node 274:
#   Impurity (MSE) = 0.15999999999999992
#   Samples = 5
#   Value = [[0.8]]
# Node 275:
#   Impurity (MSE) = 24.230623818525522
#   Samples = 207
#   Value = [[3.84057971]]
# Node 276:
#   Impurity (MSE) = 62.71428571428571
#   Samples = 14
#   Value = [[8.]]
# Node 277:
#   Impurity (MSE) = 49.87654320987653
#   Samples = 9
#   Value = [[12.11111111]]
# Node 278:
#   Impurity (MSE) = 0.64
#   Samples = 5
#   Value = [[0.6]]
# Node 279:
#   Impurity (MSE) = 20.093049477838328
#   Samples = 193
#   Value = [[3.5388601]]
# Node 280:
#   Impurity (MSE) = 16.537735315732938
#   Samples = 133
#   Value = [[2.79699248]]
# Node 281:
#   Impurity (MSE) = 71.83673469387756
#   Samples = 7
#   Value = [[8.14285714]]
# Node 282:
#   Impurity (MSE) = 11.789682539682541
#   Samples = 126
#   Value = [[2.5]]
# Node 283:
#   Impurity (MSE) = 17.76479181884587
#   Samples = 37
#   Value = [[3.72972973]]
# Node 284:
#   Impurity (MSE) = 8.415604090392627
#   Samples = 89
#   Value = [[1.98876404]]
# Node 285:
#   Impurity (MSE) = 24.04972222222222
#   Samples = 60
#   Value = [[5.18333333]]
# Node 286:
#   Impurity (MSE) = 31.596938775510203
#   Samples = 14
#   Value = [[7.78571429]]
# Node 287:
#   Impurity (MSE) = 27.555555555555554
#   Samples = 6
#   Value = [[4.66666667]]
# Node 288:
#   Impurity (MSE) = 21.859375
#   Samples = 8
#   Value = [[10.125]]
# Node 289:
#   Impurity (MSE) = 19.06427221172023
#   Samples = 46
#   Value = [[4.39130435]]
# Node 290:
#   Impurity (MSE) = 22.247933884297524
#   Samples = 11
#   Value = [[6.45454545]]
# Node 291:
#   Impurity (MSE) = 16.30530612244898
#   Samples = 35
#   Value = [[3.74285714]]
# Node 292:
#   Impurity (MSE) = 5.177809650402248
#   Samples = 8241
#   Value = [[0.8036646]]
# Node 293:
#   Impurity (MSE) = 9.276984472737016
#   Samples = 1465
#   Value = [[1.56109215]]
# Node 294:
#   Impurity (MSE) = 5.30676140045947
#   Samples = 937
#   Value = [[1.02454642]]
# Node 295:
#   Impurity (MSE) = 3.604919444028388
#   Samples = 813
#   Value = [[0.75399754]]
# Node 296:
#   Impurity (MSE) = 2.8991246881631305
#   Samples = 789
#   Value = [[0.63244613]]
# Node 297:
#   Impurity (MSE) = 0.004784578402366864
#   Samples = 208
#   Value = [[0.00480769]]
# Node 298:
#   Impurity (MSE) = 3.7437914925006144
#   Samples = 581
#   Value = [[0.85714286]]
# Node 299:
#   Impurity (MSE) = 10.354166666666664
#   Samples = 24
#   Value = [[4.75]]
# Node 300:
#   Impurity (MSE) = 18.22222222222223
#   Samples = 6
#   Value = [[6.33333333]]
# Node 301:
#   Impurity (MSE) = 6.617283950617281
#   Samples = 18
#   Value = [[4.22222222]]
# Node 302:
#   Impurity (MSE) = 12.838384495317378
#   Samples = 124
#   Value = [[2.7983871]]
# Node 303:
#   Impurity (MSE) = 10.892918701522554
#   Samples = 118
#   Value = [[2.53389831]]
# Node 304:
#   Impurity (MSE) = 51.57142857142857
#   Samples = 14
#   Value = [[5.]]
# Node 305:
#   Impurity (MSE) = 4.48807322485207
#   Samples = 104
#   Value = [[2.20192308]]
# Node 306:
#   Impurity (MSE) = 22.66666666666667
#   Samples = 6
#   Value = [[8.]]
# Node 307:
#   Impurity (MSE) = 14.905127266988064
#   Samples = 528
#   Value = [[2.51325758]]
# Node 308:
#   Impurity (MSE) = 20.31851167031826
#   Samples = 281
#   Value = [[3.55160142]]
# Node 309:
#   Impurity (MSE) = 4.195631528964862
#   Samples = 117
#   Value = [[1.44444444]]
# Node 310:
#   Impurity (MSE) = 2.0693359375
#   Samples = 64
#   Value = [[0.65625]]
# Node 311:
#   Impurity (MSE) = 5.107155571377714
#   Samples = 53
#   Value = [[2.39622642]]
# Node 312:
#   Impurity (MSE) = 26.39332986317668
#   Samples = 164
#   Value = [[5.05487805]]
# Node 313:
#   Impurity (MSE) = 30.997321645970295
#   Samples = 111
#   Value = [[5.89189189]]
# Node 314:
#   Impurity (MSE) = 12.210751156995372
#   Samples = 53
#   Value = [[3.30188679]]
# Node 315:
#   Impurity (MSE) = 6.124604566539363
#   Samples = 247
#   Value = [[1.33198381]]
# Node 316:
#   Impurity (MSE) = 3.949518775503177
#   Samples = 241
#   Value = [[1.19502075]]
# Node 317:
#   Impurity (MSE) = 2.087863498263889
#   Samples = 192
#   Value = [[1.02604167]]
# Node 318:
#   Impurity (MSE) = 10.693877551020407
#   Samples = 49
#   Value = [[1.85714286]]
# Node 319:
#   Impurity (MSE) = 62.47222222222223
#   Samples = 6
#   Value = [[6.83333333]]
# Node 320:
#   Impurity (MSE) = 4.1406979839951825
#   Samples = 6776
#   Value = [[0.63990555]]
# Node 321:
#   Impurity (MSE) = 1.2477256403153907
#   Samples = 1576
#   Value = [[0.19606599]]
# Node 322:
#   Impurity (MSE) = 1.1281794898131339
#   Samples = 1557
#   Value = [[0.16891458]]
# Node 323:
#   Impurity (MSE) = 1.0040959639582103
#   Samples = 1442
#   Value = [[0.10887656]]
# Node 324:
#   Impurity (MSE) = 0.20805064556434819
#   Samples = 1225
#   Value = [[0.05061224]]
# Node 325:
#   Impurity (MSE) = 5.37055363248317
#   Samples = 217
#   Value = [[0.43778802]]
# Node 326:
#   Impurity (MSE) = 2.0721361058601135
#   Samples = 115
#   Value = [[0.92173913]]
# Node 327:
#   Impurity (MSE) = 1.0408864265927977
#   Samples = 95
#   Value = [[0.72631579]]
# Node 328:
#   Impurity (MSE) = 5.927499999999999
#   Samples = 20
#   Value = [[1.85]]
# Node 329:
#   Impurity (MSE) = 6.0332409972299175
#   Samples = 19
#   Value = [[2.42105263]]
# Node 330:
#   Impurity (MSE) = 5.95918367346939
#   Samples = 7
#   Value = [[4.57142857]]
# Node 331:
#   Impurity (MSE) = 1.8055555555555551
#   Samples = 12
#   Value = [[1.16666667]]
# Node 332:
#   Impurity (MSE) = 0.8163265306122449
#   Samples = 7
#   Value = [[0.57142857]]
# Node 333:
#   Impurity (MSE) = 2.0
#   Samples = 5
#   Value = [[2.]]
# Node 334:
#   Impurity (MSE) = 4.939691974852071
#   Samples = 5200
#   Value = [[0.77442308]]
# Node 335:
#   Impurity (MSE) = 27.311385459533604
#   Samples = 27
#   Value = [[5.85185185]]
# Node 336:
#   Impurity (MSE) = 1.9375
#   Samples = 8
#   Value = [[2.75]]
# Node 337:
#   Impurity (MSE) = 32.2382271468144
#   Samples = 19
#   Value = [[7.15789474]]
# Node 338:
#   Impurity (MSE) = 13.714285714285722
#   Samples = 7
#   Value = [[12.]]
# Node 339:
#   Impurity (MSE) = 21.38888888888889
#   Samples = 12
#   Value = [[4.33333333]]
# Node 340:
#   Impurity (MSE) = 4.687664829006086
#   Samples = 5173
#   Value = [[0.7479219]]
# Node 341:
#   Impurity (MSE) = 10.369666699715777
#   Samples = 492
#   Value = [[1.69715447]]
# Node 342:
#   Impurity (MSE) = 16.090620662304183
#   Samples = 246
#   Value = [[2.73170732]]
# Node 343:
#   Impurity (MSE) = 2.5081135567453234
#   Samples = 246
#   Value = [[0.66260163]]
# Node 344:
#   Impurity (MSE) = 3.9857950257854675
#   Samples = 4681
#   Value = [[0.6481521]]
# Node 345:
#   Impurity (MSE) = 6.354970567867037
#   Samples = 2280
#   Value = [[0.83289474]]
# Node 346:
#   Impurity (MSE) = 1.6728292962757951
#   Samples = 2401
#   Value = [[0.4727197]]
# Node 347:
#   Impurity (MSE) = 9.39468174969843
#   Samples = 41952
#   Value = [[0.59913711]]
# Node 348:
#   Impurity (MSE) = 17.178567288517968
#   Samples = 7947
#   Value = [[1.27884736]]
# Node 349:
#   Impurity (MSE) = 15.172818130225856
#   Samples = 7752
#   Value = [[1.15208978]]
# Node 350:
#   Impurity (MSE) = 9.453739088672132
#   Samples = 3608
#   Value = [[0.56845898]]
# Node 351:
#   Impurity (MSE) = 29.495960016659723
#   Samples = 490
#   Value = [[1.65306122]]
# Node 352:
#   Impurity (MSE) = 20.7160178395261
#   Samples = 469
#   Value = [[1.39232409]]
# Node 353:
#   Impurity (MSE) = 18.340794556773215
#   Samples = 461
#   Value = [[1.27114967]]
# Node 354:
#   Impurity (MSE) = 3.593086049081545
#   Samples = 219
#   Value = [[0.68949772]]
# Node 355:
#   Impurity (MSE) = 2.289485766758494
#   Samples = 198
#   Value = [[0.53030303]]
# Node 356:
#   Impurity (MSE) = 13.392290249433106
#   Samples = 21
#   Value = [[2.19047619]]
# Node 357:
#   Impurity (MSE) = 31.103630216515263
#   Samples = 242
#   Value = [[1.79752066]]
# Node 358:
#   Impurity (MSE) = 9.952251101237582
#   Samples = 229
#   Value = [[1.52838428]]
# Node 359:
#   Impurity (MSE) = 379.94082840236683
#   Samples = 13
#   Value = [[6.53846154]]
# Node 360:
#   Impurity (MSE) = 107.984375
#   Samples = 8
#   Value = [[8.375]]
# Node 361:
#   Impurity (MSE) = 190.15419501133786
#   Samples = 21
#   Value = [[7.47619048]]
# Node 362:
#   Impurity (MSE) = 348.395061728395
#   Samples = 9
#   Value = [[13.77777778]]
# Node 363:
#   Impurity (MSE) = 19.354166666666668
#   Samples = 12
#   Value = [[2.75]]
# Node 364:
#   Impurity (MSE) = 31.840000000000003
#   Samples = 5
#   Value = [[4.6]]
# Node 365:
#   Impurity (MSE) = 6.244897959183675
#   Samples = 7
#   Value = [[1.42857143]]
# Node 366:
#   Impurity (MSE) = 6.090143576518393
#   Samples = 3118
#   Value = [[0.39801155]]
# Node 367:
#   Impurity (MSE) = 0.07745582321869225
#   Samples = 1354
#   Value = [[0.00960118]]
# Node 368:
#   Impurity (MSE) = 0.9522928994082841
#   Samples = 104
#   Value = [[0.09615385]]
# Node 369:
#   Impurity (MSE) = 5.859375
#   Samples = 16
#   Value = [[0.625]]
# Node 370:
#   Impurity (MSE) = 0.0
#   Samples = 10
#   Value = [[0.]]
# Node 371:
#   Impurity (MSE) = 13.88888888888889
#   Samples = 6
#   Value = [[1.66666667]]
# Node 372:
#   Impurity (MSE) = 0.0
#   Samples = 88
#   Value = [[0.]]
# Node 373:
#   Impurity (MSE) = 0.0039942400000000005
#   Samples = 1250
#   Value = [[0.0024]]
# Node 374:
#   Impurity (MSE) = 0.17355371900826447
#   Samples = 22
#   Value = [[0.09090909]]
# Node 375:
#   Impurity (MSE) = 0.5555555555555556
#   Samples = 6
#   Value = [[0.33333333]]
# Node 376:
#   Impurity (MSE) = 0.0
#   Samples = 16
#   Value = [[0.]]
# Node 377:
#   Impurity (MSE) = 0.0008136691105475921
#   Samples = 1228
#   Value = [[0.00081433]]
# Node 378:
#   Impurity (MSE) = 0.00806398307885518
#   Samples = 123
#   Value = [[0.00813008]]
# Node 379:
#   Impurity (MSE) = 0.0
#   Samples = 1105
#   Value = [[0.]]
# Node 380:
#   Impurity (MSE) = 10.50064273630843
#   Samples = 1764
#   Value = [[0.69614512]]
# Node 381:
#   Impurity (MSE) = 39.52903579254931
#   Samples = 74
#   Value = [[2.36486486]]
# Node 382:
#   Impurity (MSE) = 5.026509244820672
#   Samples = 67
#   Value = [[0.67164179]]
# Node 383:
#   Impurity (MSE) = 0.30082644628099175
#   Samples = 55
#   Value = [[0.09090909]]
# Node 384:
#   Impurity (MSE) = 18.055555555555557
#   Samples = 12
#   Value = [[3.33333333]]
# Node 385:
#   Impurity (MSE) = 79.673469387755
#   Samples = 7
#   Value = [[18.57142857]]
# Node 386:
#   Impurity (MSE) = 9.102307692307692
#   Samples = 1690
#   Value = [[0.62307692]]
# Node 387:
#   Impurity (MSE) = 39.63333252444855
#   Samples = 203
#   Value = [[1.57635468]]
# Node 388:
#   Impurity (MSE) = 11.586607845148935
#   Samples = 171
#   Value = [[1.0994152]]
# Node 389:
#   Impurity (MSE) = 181.796875
#   Samples = 32
#   Value = [[4.125]]
# Node 390:
#   Impurity (MSE) = 4.793326064176912
#   Samples = 1487
#   Value = [[0.4929388]]
# Node 391:
#   Impurity (MSE) = 4.561659948771189
#   Samples = 1479
#   Value = [[0.47329277]]
# Node 392:
#   Impurity (MSE) = 34.359375
#   Samples = 8
#   Value = [[4.125]]
# Node 393:
#   Impurity (MSE) = 19.597395313128903
#   Samples = 4144
#   Value = [[1.66023166]]
# Node 394:
#   Impurity (MSE) = 26.510135979860763
#   Samples = 2235
#   Value = [[2.18299776]]
# Node 395:
#   Impurity (MSE) = 10.464906768134156
#   Samples = 482
#   Value = [[1.04356846]]
# Node 396:
#   Impurity (MSE) = 6.9202097098534905
#   Samples = 472
#   Value = [[0.94067797]]
# Node 397:
#   Impurity (MSE) = 38.535714285714285
#   Samples = 14
#   Value = [[3.5]]
# Node 398:
#   Impurity (MSE) = 0.6875
#   Samples = 8
#   Value = [[0.75]]
# Node 399:
#   Impurity (MSE) = 65.47222222222221
#   Samples = 6
#   Value = [[7.16666667]]
# Node 400:
#   Impurity (MSE) = 5.747454281954959
#   Samples = 458
#   Value = [[0.86244541]]
# Node 401:
#   Impurity (MSE) = 7.513003792385485
#   Samples = 328
#   Value = [[1.14329268]]
# Node 402:
#   Impurity (MSE) = 0.591715976331361
#   Samples = 130
#   Value = [[0.15384615]]
# Node 403:
#   Impurity (MSE) = 153.69
#   Samples = 10
#   Value = [[5.9]]
# Node 404:
#   Impurity (MSE) = 70.56
#   Samples = 5
#   Value = [[4.2]]
# Node 405:
#   Impurity (MSE) = 231.04000000000002
#   Samples = 5
#   Value = [[7.6]]
# Node 406:
#   Impurity (MSE) = 30.46675750054751
#   Samples = 1753
#   Value = [[2.49629207]]
# Node 407:
#   Impurity (MSE) = 35.25487273050908
#   Samples = 424
#   Value = [[3.63679245]]
# Node 408:
#   Impurity (MSE) = 15.661428571428573
#   Samples = 140
#   Value = [[1.9]]
# Node 409:
#   Impurity (MSE) = 36.86522024983563
#   Samples = 39
#   Value = [[4.48717949]]
# Node 410:
#   Impurity (MSE) = 3.891187138515831
#   Samples = 101
#   Value = [[0.9009901]]
# Node 411:
#   Impurity (MSE) = 42.69361237849633
#   Samples = 284
#   Value = [[4.49295775]]
# Node 412:
#   Impurity (MSE) = 72.75045913682277
#   Samples = 66
#   Value = [[6.71212121]]
# Node 413:
#   Impurity (MSE) = 31.651481356788153
#   Samples = 218
#   Value = [[3.82110092]]
# Node 414:
#   Impurity (MSE) = 28.391792513026253
#   Samples = 1329
#   Value = [[2.1324304]]
# Node 415:
#   Impurity (MSE) = 26.394736482369666
#   Samples = 1012
#   Value = [[1.79743083]]
# Node 416:
#   Impurity (MSE) = 48.836734693877546
#   Samples = 14
#   Value = [[9.14285714]]
# Node 417:
#   Impurity (MSE) = 25.312413403962232
#   Samples = 998
#   Value = [[1.69438878]]
# Node 418:
#   Impurity (MSE) = 33.26523301057827
#   Samples = 317
#   Value = [[3.20189274]]
# Node 419:
#   Impurity (MSE) = 13.695118592928722
#   Samples = 289
#   Value = [[2.62283737]]
# Node 420:
#   Impurity (MSE) = 196.07525510204079
#   Samples = 28
#   Value = [[9.17857143]]
# Node 421:
#   Impurity (MSE) = 10.809620882692636
#   Samples = 1909
#   Value = [[1.04819277]]
# Node 422:
#   Impurity (MSE) = 8.662956806890511
#   Samples = 1873
#   Value = [[0.97383876]]
# Node 423:
#   Impurity (MSE) = 11.648745628245695
#   Samples = 257
#   Value = [[2.11284047]]
# Node 424:
#   Impurity (MSE) = 8.38318268483864
#   Samples = 238
#   Value = [[1.77731092]]
# Node 425:
#   Impurity (MSE) = 12.97520661157024
#   Samples = 11
#   Value = [[4.54545455]]
# Node 426:
#   Impurity (MSE) = 7.771352054183081
#   Samples = 227
#   Value = [[1.64317181]]
# Node 427:
#   Impurity (MSE) = 33.479224376731295
#   Samples = 19
#   Value = [[6.31578947]]
# Node 428:
#   Impurity (MSE) = 45.89
#   Samples = 10
#   Value = [[8.1]]
# Node 429:
#   Impurity (MSE) = 12.222222222222225
#   Samples = 9
#   Value = [[4.33333333]]
# Node 430:
#   Impurity (MSE) = 7.948981334550535
#   Samples = 1616
#   Value = [[0.79269802]]
# Node 431:
#   Impurity (MSE) = 7.2278180530080265
#   Samples = 1605
#   Value = [[0.76012461]]
# Node 432:
#   Impurity (MSE) = 5.152520412429139
#   Samples = 1513
#   Value = [[0.66358229]]
# Node 433:
#   Impurity (MSE) = 38.683364839319474
#   Samples = 92
#   Value = [[2.34782609]]
# Node 434:
#   Impurity (MSE) = 90.4297520661157
#   Samples = 11
#   Value = [[5.54545455]]
# Node 435:
#   Impurity (MSE) = 125.13888888888889
#   Samples = 6
#   Value = [[9.83333333]]
# Node 436:
#   Impurity (MSE) = 0.24
#   Samples = 5
#   Value = [[0.4]]
# Node 437:
#   Impurity (MSE) = 107.24305555555554
#   Samples = 36
#   Value = [[4.91666667]]
# Node 438:
#   Impurity (MSE) = 248.80555555555554
#   Samples = 6
#   Value = [[21.16666667]]
# Node 439:
#   Impurity (MSE) = 15.555555555555554
#   Samples = 30
#   Value = [[1.66666667]]
# Node 440:
#   Impurity (MSE) = 0.48
#   Samples = 25
#   Value = [[0.4]]
# Node 441:
#   Impurity (MSE) = 0.2275
#   Samples = 20
#   Value = [[0.15]]
# Node 442:
#   Impurity (MSE) = 0.24000000000000044
#   Samples = 5
#   Value = [[1.4]]
# Node 443:
#   Impurity (MSE) = 42.8
#   Samples = 5
#   Value = [[8.]]
# Node 444:
#   Impurity (MSE) = 70.88352399737016
#   Samples = 195
#   Value = [[6.31794872]]
# Node 445:
#   Impurity (MSE) = 50.69972222222222
#   Samples = 120
#   Value = [[3.81666667]]
# Node 446:
#   Impurity (MSE) = 31.3721048872564
#   Samples = 99
#   Value = [[2.95959596]]
# Node 447:
#   Impurity (MSE) = 12.7129537790121
#   Samples = 71
#   Value = [[1.81690141]]
# Node 448:
#   Impurity (MSE) = 0.16
#   Samples = 15
#   Value = [[0.2]]
# Node 449:
#   Impurity (MSE) = 0.24489795918367346
#   Samples = 7
#   Value = [[0.42857143]]
# Node 450:
#   Impurity (MSE) = 0.0
#   Samples = 8
#   Value = [[0.]]
# Node 451:
#   Impurity (MSE) = 15.1875
#   Samples = 56
#   Value = [[2.25]]
# Node 452:
#   Impurity (MSE) = 30.576388888888886
#   Samples = 12
#   Value = [[3.91666667]]
# Node 453:
#   Impurity (MSE) = 6.571428571428571
#   Samples = 7
#   Value = [[2.]]
# Node 454:
#   Impurity (MSE) = 51.84000000000001
#   Samples = 5
#   Value = [[6.6]]
# Node 455:
#   Impurity (MSE) = 10.026342975206612
#   Samples = 44
#   Value = [[1.79545455]]
# Node 456:
#   Impurity (MSE) = 1.9659763313609468
#   Samples = 26
#   Value = [[0.73076923]]
# Node 457:
#   Impurity (MSE) = 17.666666666666664
#   Samples = 18
#   Value = [[3.33333333]]
# Node 458:
#   Impurity (MSE) = 66.9795918367347
#   Samples = 28
#   Value = [[5.85714286]]
# Node 459:
#   Impurity (MSE) = 97.09
#   Samples = 10
#   Value = [[12.9]]
# Node 460:
#   Impurity (MSE) = 36.96000000000001
#   Samples = 5
#   Value = [[8.2]]
# Node 461:
#   Impurity (MSE) = 113.03999999999996
#   Samples = 5
#   Value = [[17.6]]
# Node 462:
#   Impurity (MSE) = 7.385802469135802
#   Samples = 18
#   Value = [[1.94444444]]
# Node 463:
#   Impurity (MSE) = 8.444444444444445
#   Samples = 9
#   Value = [[3.33333333]]
# Node 464:
#   Impurity (MSE) = 2.4691358024691357
#   Samples = 9
#   Value = [[0.55555556]]
# Node 465:
#   Impurity (MSE) = 122.02721088435374
#   Samples = 21
#   Value = [[7.85714286]]
# Node 466:
#   Impurity (MSE) = 141.80859375
#   Samples = 16
#   Value = [[9.9375]]
# Node 467:
#   Impurity (MSE) = 35.45
#   Samples = 10
#   Value = [[5.5]]
# Node 468:
#   Impurity (MSE) = 231.5555555555556
#   Samples = 6
#   Value = [[17.33333333]]
# Node 469:
#   Impurity (MSE) = 0.56
#   Samples = 5
#   Value = [[1.2]]
# Node 470:
#   Impurity (MSE) = 77.15093333333333
#   Samples = 75
#   Value = [[10.32]]
# Node 471:
#   Impurity (MSE) = 73.46559015763168
#   Samples = 51
#   Value = [[13.49019608]]
# Node 472:
#   Impurity (MSE) = 45.00382653061223
#   Samples = 28
#   Value = [[9.67857143]]
# Node 473:
#   Impurity (MSE) = 10.96
#   Samples = 5
#   Value = [[2.8]]
# Node 474:
#   Impurity (MSE) = 39.88279773156897
#   Samples = 23
#   Value = [[11.17391304]]
# Node 475:
#   Impurity (MSE) = 25.484375
#   Samples = 16
#   Value = [[9.125]]
# Node 476:
#   Impurity (MSE) = 17.25
#   Samples = 6
#   Value = [[5.5]]
# Node 477:
#   Impurity (MSE) = 17.809999999999988
#   Samples = 10
#   Value = [[11.3]]
# Node 478:
#   Impurity (MSE) = 41.265306122448976
#   Samples = 7
#   Value = [[15.85714286]]
# Node 479:
#   Impurity (MSE) = 68.89603024574672
#   Samples = 23
#   Value = [[18.13043478]]
# Node 480:
#   Impurity (MSE) = 62.3125
#   Samples = 16
#   Value = [[21.25]]
# Node 481:
#   Impurity (MSE) = 45.15702479338836
#   Samples = 11
#   Value = [[18.54545455]]
# Node 482:
#   Impurity (MSE) = 45.360000000000014
#   Samples = 5
#   Value = [[22.8]]
# Node 483:
#   Impurity (MSE) = 17.333333333333343
#   Samples = 6
#   Value = [[15.]]
# Node 484:
#   Impurity (MSE) = 48.56000000000006
#   Samples = 5
#   Value = [[27.2]]
# Node 485:
#   Impurity (MSE) = 10.857142857142861
#   Samples = 7
#   Value = [[11.]]
# Node 486:
#   Impurity (MSE) = 18.243055555555554
#   Samples = 24
#   Value = [[3.58333333]]
# Node 487:
#   Impurity (MSE) = 26.48979591836735
#   Samples = 7
#   Value = [[7.28571429]]
# Node 488:
#   Impurity (MSE) = 6.878892733564014
#   Samples = 17
#   Value = [[2.05882353]]
# Node 489:
#   Impurity (MSE) = 1.1875
#   Samples = 12
#   Value = [[1.25]]
# Node 490:
#   Impurity (MSE) = 0.8055555555555555
#   Samples = 6
#   Value = [[0.83333333]]
# Node 491:
#   Impurity (MSE) = 1.2222222222222219
#   Samples = 6
#   Value = [[1.66666667]]
# Node 492:
#   Impurity (MSE) = 15.2
#   Samples = 5
#   Value = [[4.]]
# Node 493:
#   Impurity (MSE) = 7.442376273363019
#   Samples = 34005
#   Value = [[0.44028819]]
# Node 494:
#   Impurity (MSE) = 9.353352467339624
#   Samples = 26567
#   Value = [[0.55030677]]
# Node 495:
#   Impurity (MSE) = 8.675396919946966
#   Samples = 23580
#   Value = [[0.4625106]]
# Node 496:
#   Impurity (MSE) = 3.6542535312842004
#   Samples = 13727
#   Value = [[0.28957529]]
# Node 497:
#   Impurity (MSE) = 5.641143723587773
#   Samples = 6620
#   Value = [[0.46389728]]
# Node 498:
#   Impurity (MSE) = 4.609949533498563
#   Samples = 4964
#   Value = [[0.32091056]]
# Node 499:
#   Impurity (MSE) = 2.385019415713347
#   Samples = 3655
#   Value = [[0.2123119]]
# Node 500:
#   Impurity (MSE) = 2.1714998454104117
#   Samples = 3638
#   Value = [[0.19901045]]
# Node 501:
#   Impurity (MSE) = 39.93771626297578
#   Samples = 17
#   Value = [[3.05882353]]
# Node 502:
#   Impurity (MSE) = 10.697537935932758
#   Samples = 1309
#   Value = [[0.62414057]]
# Node 503:
#   Impurity (MSE) = 3.804303133228509
#   Samples = 1222
#   Value = [[0.47708674]]
# Node 504:
#   Impurity (MSE) = 102.94966309948474
#   Samples = 87
#   Value = [[2.68965517]]
# Node 505:
#   Impurity (MSE) = 8.487238617003896
#   Samples = 1656
#   Value = [[0.89251208]]
# Node 506:
#   Impurity (MSE) = 17.026666666666667
#   Samples = 30
#   Value = [[5.2]]
# Node 507:
#   Impurity (MSE) = 2.321329639889198
#   Samples = 19
#   Value = [[3.68421053]]
# Node 508:
#   Impurity (MSE) = 31.603305785123972
#   Samples = 11
#   Value = [[7.81818182]]
# Node 509:
#   Impurity (MSE) = 7.981035419210281
#   Samples = 1626
#   Value = [[0.81303813]]
# Node 510:
#   Impurity (MSE) = 6.9643462215271255
#   Samples = 1611
#   Value = [[0.76970826]]
# Node 511:
#   Impurity (MSE) = 95.31555555555556
#   Samples = 15
#   Value = [[5.46666667]]
# Node 512:
#   Impurity (MSE) = 1.7488409346932294
#   Samples = 7107
#   Value = [[0.12719854]]
# Node 513:
#   Impurity (MSE) = 1.5333806481189896
#   Samples = 6991
#   Value = [[0.11099986]]
# Node 514:
#   Impurity (MSE) = 0.6675668773112415
#   Samples = 3871
#   Value = [[0.03539137]]
# Node 515:
#   Impurity (MSE) = 0.05355544917839618
#   Samples = 2816
#   Value = [[0.00816761]]
# Node 516:
#   Impurity (MSE) = 2.299224186339031
#   Samples = 1055
#   Value = [[0.10805687]]
# Node 517:
#   Impurity (MSE) = 2.591707655325444
#   Samples = 3120
#   Value = [[0.20480769]]
# Node 518:
#   Impurity (MSE) = 7.3350749731444225
#   Samples = 687
#   Value = [[0.47161572]]
# Node 519:
#   Impurity (MSE) = 1.2265585762554843
#   Samples = 2433
#   Value = [[0.12946979]]
# Node 520:
#   Impurity (MSE) = 13.765160523186683
#   Samples = 116
#   Value = [[1.10344828]]
# Node 521:
#   Impurity (MSE) = 56.48668639053254
#   Samples = 26
#   Value = [[2.88461538]]
# Node 522:
#   Impurity (MSE) = 0.15419501133786848
#   Samples = 21
#   Value = [[0.19047619]]
# Node 523:
#   Impurity (MSE) = 134.56
#   Samples = 5
#   Value = [[14.2]]
# Node 524:
#   Impurity (MSE) = 0.24209876543209874
#   Samples = 90
#   Value = [[0.58888889]]
# Node 525:
#   Impurity (MSE) = 0.06525084641428136
#   Samples = 57
#   Value = [[0.92982456]]
# Node 526:
#   Impurity (MSE) = 0.0
#   Samples = 33
#   Value = [[0.]]
# Node 527:
#   Impurity (MSE) = 15.57103961884274
#   Samples = 9853
#   Value = [[0.70344058]]
# Node 528:
#   Impurity (MSE) = 53.168367346938794
#   Samples = 14
#   Value = [[27.21428571]]
# Node 529:
#   Impurity (MSE) = 14.0
#   Samples = 8
#   Value = [[30.5]]
# Node 530:
#   Impurity (MSE) = 71.80555555555554
#   Samples = 6
#   Value = [[22.83333333]]
# Node 531:
#   Impurity (MSE) = 14.516063289145299
#   Samples = 9839
#   Value = [[0.66571806]]
# Node 532:
#   Impurity (MSE) = 114.83095941951088
#   Samples = 61
#   Value = [[4.70491803]]
# Node 533:
#   Impurity (MSE) = 208.19674556213013
#   Samples = 26
#   Value = [[10.26923077]]
# Node 534:
#   Impurity (MSE) = 276.3822222222222
#   Samples = 15
#   Value = [[16.13333333]]
# Node 535:
#   Impurity (MSE) = 4.380165289256197
#   Samples = 11
#   Value = [[2.27272727]]
# Node 536:
#   Impurity (MSE) = 5.387755102040816
#   Samples = 35
#   Value = [[0.57142857]]
# Node 537:
#   Impurity (MSE) = 0.0
#   Samples = 29
#   Value = [[0.]]
# Node 538:
#   Impurity (MSE) = 22.22222222222222
#   Samples = 6
#   Value = [[3.33333333]]
# Node 539:
#   Impurity (MSE) = 13.787832497521894
#   Samples = 9778
#   Value = [[0.64051953]]
# Node 540:
#   Impurity (MSE) = 12.512919022217789
#   Samples = 8231
#   Value = [[0.51524724]]
# Node 541:
#   Impurity (MSE) = 14.203718738881452
#   Samples = 7213
#   Value = [[0.58311382]]
# Node 542:
#   Impurity (MSE) = 0.2689554618053813
#   Samples = 1018
#   Value = [[0.03438114]]
# Node 543:
#   Impurity (MSE) = 20.04340866175917
#   Samples = 1547
#   Value = [[1.3070459]]
# Node 544:
#   Impurity (MSE) = 15.464924203367236
#   Samples = 1518
#   Value = [[1.15019763]]
# Node 545:
#   Impurity (MSE) = 191.00832342449468
#   Samples = 29
#   Value = [[9.51724138]]
# Node 546:
#   Impurity (MSE) = 14.164063245159333
#   Samples = 2987
#   Value = [[1.24338801]]
# Node 547:
#   Impurity (MSE) = 8.997032472776677
#   Samples = 2391
#   Value = [[0.86574655]]
# Node 548:
#   Impurity (MSE) = 1.7436634450993058
#   Samples = 477
#   Value = [[0.14675052]]
# Node 549:
#   Impurity (MSE) = 13.1584
#   Samples = 50
#   Value = [[1.04]]
# Node 550:
#   Impurity (MSE) = 0.0
#   Samples = 43
#   Value = [[0.]]
# Node 551:
#   Impurity (MSE) = 46.53061224489795
#   Samples = 7
#   Value = [[7.42857143]]
# Node 552:
#   Impurity (MSE) = 0.3026726412145078
#   Samples = 427
#   Value = [[0.04215457]]
# Node 553:
#   Impurity (MSE) = 2.8382909680908597
#   Samples = 43
#   Value = [[0.37209302]]
# Node 554:
#   Impurity (MSE) = 7.836734693877551
#   Samples = 14
#   Value = [[1.14285714]]
# Node 555:
#   Impurity (MSE) = 0.0
#   Samples = 29
#   Value = [[0.]]
# Node 556:
#   Impurity (MSE) = 0.005181206597222222
#   Samples = 384
#   Value = [[0.00520833]]
# Node 557:
#   Impurity (MSE) = 0.01448961937716263
#   Samples = 136
#   Value = [[0.01470588]]
# Node 558:
#   Impurity (MSE) = 0.0
#   Samples = 248
#   Value = [[0.]]
# Node 559:
#   Impurity (MSE) = 10.64374913331783
#   Samples = 1914
#   Value = [[1.04493208]]
# Node 560:
#   Impurity (MSE) = 21.503676431580175
#   Samples = 307
#   Value = [[2.26384365]]
# Node 561:
#   Impurity (MSE) = 111.64803804994054
#   Samples = 29
#   Value = [[6.72413793]]
# Node 562:
#   Impurity (MSE) = 6.608024691358026
#   Samples = 18
#   Value = [[2.05555556]]
# Node 563:
#   Impurity (MSE) = 189.50413223140495
#   Samples = 11
#   Value = [[14.36363636]]
# Node 564:
#   Impurity (MSE) = 9.80834325345479
#   Samples = 278
#   Value = [[1.79856115]]
# Node 565:
#   Impurity (MSE) = 17.931972789115644
#   Samples = 21
#   Value = [[4.14285714]]
# Node 566:
#   Impurity (MSE) = 8.658783630335053
#   Samples = 257
#   Value = [[1.60700389]]
# Node 567:
#   Impurity (MSE) = 8.231017921360694
#   Samples = 1607
#   Value = [[0.81207218]]
# Node 568:
#   Impurity (MSE) = 56.53061224489795
#   Samples = 7
# ...
#   Impurity (MSE) = 229.25
#   Samples = 16
#   Value = [[33.5]]
# Node 943:
#   Impurity (MSE) = 159.109375
#   Samples = 8
#   Value = [[41.875]]
# Node 944:
#   Impurity (MSE) = 159.109375
#   Samples = 8
#   Value = [[25.125]]
# Node 945:
#   Impurity (MSE) = 17.74609375
#   Samples = 16
#   Value = [[5.5625]]
# Node 946:
#   Impurity (MSE) = 15.650000000000006
#   Samples = 10
#   Value = [[7.5]]
# Node 947:
#   Impurity (MSE) = 2.799999999999997
#   Samples = 5
#   Value = [[6.]]
# Node 948:
#   Impurity (MSE) = 24.0
#   Samples = 5
#   Value = [[9.]]
# Node 949:
#   Impurity (MSE) = 4.5555555555555545
#   Samples = 6
#   Value = [[2.33333333]]
# Node 950:
#   Impurity (MSE) = 63.66196407199025
#   Samples = 598
#   Value = [[4.82107023]]
# Node 951:
#   Impurity (MSE) = 262.62109375
#   Samples = 16
#   Value = [[15.5625]]
# Node 952:
#   Impurity (MSE) = 14.222222222222229
#   Samples = 6
#   Value = [[6.33333333]]
# Node 953:
#   Impurity (MSE) = 329.89
#   Samples = 10
#   Value = [[21.1]]
# Node 954:
#   Impurity (MSE) = 257.20000000000005
#   Samples = 5
#   Value = [[33.]]
# Node 955:
#   Impurity (MSE) = 119.36000000000001
#   Samples = 5
#   Value = [[9.2]]
# Node 956:
#   Impurity (MSE) = 54.933184539625174
#   Samples = 582
#   Value = [[4.5257732]]
# Node 957:
#   Impurity (MSE) = 33.08853978636199
#   Samples = 434
#   Value = [[3.43087558]]
# Node 958:
#   Impurity (MSE) = 29.864356311908757
#   Samples = 429
#   Value = [[3.2983683]]
# Node 959:
#   Impurity (MSE) = 6.854137273829856
#   Samples = 201
#   Value = [[1.960199]]
# Node 960:
#   Impurity (MSE) = 7.692927107745928
#   Samples = 129
#   Value = [[1.37984496]]
# Node 961:
#   Impurity (MSE) = 3.666666666666666
#   Samples = 72
#   Value = [[3.]]
# Node 962:
#   Impurity (MSE) = 47.17934364419821
#   Samples = 228
#   Value = [[4.47807018]]
# Node 963:
#   Impurity (MSE) = 12.801106770833332
#   Samples = 96
#   Value = [[2.03125]]
# Node 964:
#   Impurity (MSE) = 64.66092745638198
#   Samples = 132
#   Value = [[6.25757576]]
# Node 965:
#   Impurity (MSE) = 178.95999999999998
#   Samples = 5
#   Value = [[14.8]]
# Node 966:
#   Impurity (MSE) = 105.16704711468223
#   Samples = 148
#   Value = [[7.73648649]]
# Node 967:
#   Impurity (MSE) = 7.465277777777779
#   Samples = 36
#   Value = [[2.41666667]]
# Node 968:
#   Impurity (MSE) = 11.576388888888886
#   Samples = 12
#   Value = [[4.41666667]]
# Node 969:
#   Impurity (MSE) = 2.56
#   Samples = 5
#   Value = [[0.8]]
# Node 970:
#   Impurity (MSE) = 2.0
#   Samples = 7
#   Value = [[7.]]
# Node 971:
#   Impurity (MSE) = 2.4097222222222223
#   Samples = 24
#   Value = [[1.41666667]]
# Node 972:
#   Impurity (MSE) = 1.359375
#   Samples = 16
#   Value = [[0.625]]
# Node 973:
#   Impurity (MSE) = 0.75
#   Samples = 8
#   Value = [[3.]]
# Node 974:
#   Impurity (MSE) = 124.55070153061224
#   Samples = 112
#   Value = [[9.44642857]]
# Node 975:
#   Impurity (MSE) = 62.632797731569
#   Samples = 92
#   Value = [[7.67391304]]
# Node 976:
#   Impurity (MSE) = 65.53979591836737
#   Samples = 70
#   Value = [[9.21428571]]
# Node 977:
#   Impurity (MSE) = 21.811983471074377
#   Samples = 22
#   Value = [[2.77272727]]
# Node 978:
#   Impurity (MSE) = 328.44
#   Samples = 20
#   Value = [[17.6]]
# Node 979:
#   Impurity (MSE) = 373.234375
#   Samples = 8
#   Value = [[33.375]]
# Node 980:
#   Impurity (MSE) = 22.076388888888893
#   Samples = 12
#   Value = [[7.08333333]]
# Node 981:
#   Impurity (MSE) = 22.45973806733109
#   Samples = 841
#   Value = [[2.12604043]]
# Node 982:
#   Impurity (MSE) = 7.165617146570513
#   Samples = 417
#   Value = [[1.08393285]]
# Node 983:
#   Impurity (MSE) = 12.0471
#   Samples = 200
#   Value = [[1.77]]
# Node 984:
#   Impurity (MSE) = 7.243392504930967
#   Samples = 195
#   Value = [[1.46153846]]
# Node 985:
#   Impurity (MSE) = 29.632653061224485
#   Samples = 7
#   Value = [[4.71428571]]
# Node 986:
#   Impurity (MSE) = 6.001131733816207
#   Samples = 188
#   Value = [[1.34042553]]
# Node 987:
#   Impurity (MSE) = 15.555555555555557
#   Samples = 9
#   Value = [[3.66666667]]
# Node 988:
#   Impurity (MSE) = 5.234980181642271
#   Samples = 179
#   Value = [[1.22346369]]
# Node 989:
#   Impurity (MSE) = 8.883469387755103
#   Samples = 70
#   Value = [[1.87142857]]
# Node 990:
#   Impurity (MSE) = 2.4491204444070362
#   Samples = 109
#   Value = [[0.80733945]]
# Node 991:
#   Impurity (MSE) = 50.95999999999998
#   Samples = 5
#   Value = [[13.8]]
# Node 992:
#   Impurity (MSE) = 1.8329121450869628
#   Samples = 217
#   Value = [[0.4516129]]
# Node 993:
#   Impurity (MSE) = 5.15413737155219
#   Samples = 43
#   Value = [[1.09302326]]
# Node 994:
#   Impurity (MSE) = 8.489795918367346
#   Samples = 14
#   Value = [[2.71428571]]
# Node 995:
#   Impurity (MSE) = 0.0
#   Samples = 6
#   Value = [[0.]]
# Node 996:
#   Impurity (MSE) = 5.1875
#   Samples = 8
#   Value = [[4.75]]
# Node 997:
#   Impurity (MSE) = 1.66230677764566
#   Samples = 29
#   Value = [[0.31034483]]
# Node 998:
#   Impurity (MSE) = 0.03993055555555555
#   Samples = 24
#   Value = [[0.04166667]]
# Node 999:
#   Impurity (MSE) = 0.16
#   Samples = 5
#   Value = [[0.2]]
# Node 1000:
#   Impurity (MSE) = 0.0
#   Samples = 19
#   Value = [[0.]]
# Node 1001:
#   Impurity (MSE) = 7.4399999999999995
#   Samples = 5
#   Value = [[1.6]]
# Node 1002:
#   Impurity (MSE) = 0.885354736424891
#   Samples = 174
#   Value = [[0.29310345]]
# Node 1003:
#   Impurity (MSE) = 0.5219425154320988
#   Samples = 144
#   Value = [[0.20138889]]
# Node 1004:
#   Impurity (MSE) = 0.9855102040816327
#   Samples = 70
#   Value = [[0.41428571]]
# Node 1005:
#   Impurity (MSE) = 1.363421550094518
#   Samples = 46
#   Value = [[0.63043478]]
# Node 1006:
#   Impurity (MSE) = 0.0
#   Samples = 24
#   Value = [[0.]]
# Node 1007:
#   Impurity (MSE) = 0.0
#   Samples = 74
#   Value = [[0.]]
# Node 1008:
#   Impurity (MSE) = 2.395555555555555
#   Samples = 30
#   Value = [[0.73333333]]
# Node 1009:
#   Impurity (MSE) = 1.0464
#   Samples = 25
#   Value = [[0.44]]
# Node 1010:
#   Impurity (MSE) = 1.5288888888888892
#   Samples = 15
#   Value = [[0.73333333]]
# Node 1011:
#   Impurity (MSE) = 0.0
#   Samples = 10
#   Value = [[0.]]
# Node 1012:
#   Impurity (MSE) = 6.56
#   Samples = 5
#   Value = [[2.2]]
# Node 1013:
#   Impurity (MSE) = 35.382876468494125
#   Samples = 424
#   Value = [[3.1509434]]
# Node 1014:
#   Impurity (MSE) = 73.12560843699296
#   Samples = 86
#   Value = [[5.77906977]]
# Node 1015:
#   Impurity (MSE) = 117.09297052154194
#   Samples = 42
#   Value = [[9.38095238]]
# Node 1016:
#   Impurity (MSE) = 67.168044077135
#   Samples = 33
#   Value = [[6.27272727]]
# Node 1017:
#   Impurity (MSE) = 40.13888888888886
#   Samples = 6
#   Value = [[19.16666667]]
# Node 1018:
#   Impurity (MSE) = 28.019204389574757
#   Samples = 27
#   Value = [[3.40740741]]
# Node 1019:
#   Impurity (MSE) = 31.576388888888886
#   Samples = 12
#   Value = [[7.58333333]]
# Node 1020:
#   Impurity (MSE) = 0.06222222222222222
#   Samples = 15
#   Value = [[0.06666667]]
# Node 1021:
#   Impurity (MSE) = 134.83950617283944
#   Samples = 9
#   Value = [[20.77777778]]
# Node 1022:
#   Impurity (MSE) = 6.951962809917355
#   Samples = 44
#   Value = [[2.34090909]]
# Node 1023:
#   Impurity (MSE) = 8.720000000000002
#   Samples = 25
#   Value = [[3.4]]
# Node 1024:
#   Impurity (MSE) = 5.772853185595569
#   Samples = 19
#   Value = [[2.26315789]]
# Node 1025:
#   Impurity (MSE) = 3.41
#   Samples = 10
#   Value = [[3.7]]
# Node 1026:
#   Impurity (MSE) = 3.5555555555555554
#   Samples = 9
#   Value = [[0.66666667]]
# Node 1027:
#   Impurity (MSE) = 1.0
#   Samples = 6
#   Value = [[7.]]
# Node 1028:
#   Impurity (MSE) = 1.2077562326869806
#   Samples = 19
#   Value = [[0.94736842]]
# Node 1029:
#   Impurity (MSE) = 1.1597633136094676
#   Samples = 13
#   Value = [[0.61538462]]
# Node 1030:
#   Impurity (MSE) = 0.0
#   Samples = 5
#   Value = [[0.]]
# Node 1031:
#   Impurity (MSE) = 1.5
#   Samples = 8
#   Value = [[1.]]
# Node 1032:
#   Impurity (MSE) = 0.5555555555555554
#   Samples = 6
#   Value = [[1.66666667]]
# Node 1033:
#   Impurity (MSE) = 23.575128671965267
#   Samples = 338
#   Value = [[2.48224852]]
# Node 1034:
#   Impurity (MSE) = 43.826029479807
#   Samples = 123
#   Value = [[3.94308943]]
# Node 1035:
#   Impurity (MSE) = 51.403537326388886
#   Samples = 96
#   Value = [[4.94791667]]
# Node 1036:
#   Impurity (MSE) = 31.7461659219901
#   Samples = 91
#   Value = [[4.03296703]]
# Node 1037:
#   Impurity (MSE) = 45.061899269511734
#   Samples = 51
#   Value = [[5.60784314]]
# Node 1038:
#   Impurity (MSE) = 7.574375000000001
#   Samples = 40
#   Value = [[2.025]]
# Node 1039:
#   Impurity (MSE) = 116.63999999999999
#   Samples = 5
#   Value = [[21.6]]
# Node 1040:
#   Impurity (MSE) = 0.5294924554183813
#   Samples = 27
#   Value = [[0.37037037]]
# Node 1041:
#   Impurity (MSE) = 0.20867768595041322
#   Samples = 22
#   Value = [[0.13636364]]
# Node 1042:
#   Impurity (MSE) = 0.0
#   Samples = 17
#   Value = [[0.]]
# Node 1043:
#   Impurity (MSE) = 0.64
#   Samples = 5
#   Value = [[0.6]]
# Node 1044:
#   Impurity (MSE) = 0.6400000000000003
#   Samples = 5
#   Value = [[1.4]]
# Node 1045:
#   Impurity (MSE) = 10.070394808004327
#   Samples = 215
#   Value = [[1.64651163]]
# Node 1046:
#   Impurity (MSE) = 7.690803781964698
#   Samples = 209
#   Value = [[1.38277512]]
# Node 1047:
#   Impurity (MSE) = 15.486520534139583
#   Samples = 63
#   Value = [[2.53968254]]
# Node 1048:
#   Impurity (MSE) = 20.644374999999997
#   Samples = 40
#   Value = [[3.575]]
# Node 1049:
#   Impurity (MSE) = 1.4102079395085068
#   Samples = 23
#   Value = [[0.73913043]]
# Node 1050:
#   Impurity (MSE) = 3.5001407393507225
#   Samples = 146
#   Value = [[0.88356164]]
# Node 1051:
#   Impurity (MSE) = 2.0258024691358028
#   Samples = 90
#   Value = [[0.45555556]]
# Node 1052:
#   Impurity (MSE) = 5.1020408163265305
#   Samples = 56
#   Value = [[1.57142857]]
# Node 1053:
#   Impurity (MSE) = 6.1388888888888715
#   Samples = 6
#   Value = [[10.83333333]]
# Node 1054:
#   Impurity (MSE) = 10.68819520982079
#   Samples = 3538
#   Value = [[1.57066139]]
# Node 1055:
#   Impurity (MSE) = 12.175044543916094
#   Samples = 2907
#   Value = [[1.88544892]]
# Node 1056:
#   Impurity (MSE) = 10.434099098194284
#   Samples = 2892
#   Value = [[1.84266943]]
# Node 1057:
#   Impurity (MSE) = 9.138997326402151
#   Samples = 2694
#   Value = [[1.69933185]]
# Node 1058:
#   Impurity (MSE) = 7.649661378294902
#   Samples = 2056
#   Value = [[1.42266537]]
# Node 1059:
#   Impurity (MSE) = 5.098599999999999
#   Samples = 1600
#   Value = [[1.08]]
# Node 1060:
#   Impurity (MSE) = 3.8784572941028186
#   Samples = 1414
#   Value = [[0.9009901]]
# Node 1061:
#   Impurity (MSE) = 34.33333333333333
#   Samples = 6
#   Value = [[9.]]
# Node 1062:
#   Impurity (MSE) = 3.4679671358471076
#   Samples = 1408
#   Value = [[0.86647727]]
# Node 1063:
#   Impurity (MSE) = 12.278760550352644
#   Samples = 186
#   Value = [[2.44086022]]
# Node 1064:
#   Impurity (MSE) = 10.98939527837394
#   Samples = 178
#   Value = [[2.25842697]]
# Node 1065:
#   Impurity (MSE) = 23.75
#   Samples = 8
#   Value = [[6.5]]
# Node 1066:
#   Impurity (MSE) = 14.743146929824562
#   Samples = 456
#   Value = [[2.625]]
# Node 1067:
#   Impurity (MSE) = 7.599806777645661
#   Samples = 232
#   Value = [[1.93965517]]
# Node 1068:
#   Impurity (MSE) = 4.723314276764038
#   Samples = 226
#   Value = [[1.85840708]]
# Node 1069:
#   Impurity (MSE) = 106.33333333333334
#   Samples = 6
#   Value = [[5.]]
# Node 1070:
#   Impurity (MSE) = 21.151287468112248
#   Samples = 224
#   Value = [[3.33482143]]
# Node 1071:
#   Impurity (MSE) = 13.575385256143274
#   Samples = 196
#   Value = [[2.83673469]]
# Node 1072:
#   Impurity (MSE) = 60.28954081632653
#   Samples = 28
#   Value = [[6.82142857]]
# Node 1073:
#   Impurity (MSE) = 12.896907950983184
#   Samples = 638
#   Value = [[2.59090909]]
# Node 1074:
#   Impurity (MSE) = 44.06353305785124
#   Samples = 44
#   Value = [[7.56818182]]
# Node 1075:
#   Impurity (MSE) = 17.222222222222225
#   Samples = 30
#   Value = [[4.33333333]]
# Node 1076:
#   Impurity (MSE) = 0.6388888888888886
#   Samples = 12
#   Value = [[1.16666667]]
# Node 1077:
#   Impurity (MSE) = 17.135802469135797
#   Samples = 18
#   Value = [[6.44444444]]
# Node 1078:
#   Impurity (MSE) = 31.10714285714286
#   Samples = 14
#   Value = [[14.5]]
# Node 1079:
#   Impurity (MSE) = 39.47222222222224
#   Samples = 6
#   Value = [[10.16666667]]
# Node 1080:
#   Impurity (MSE) = 0.1875
#   Samples = 8
#   Value = [[17.75]]
# Node 1081:
#   Impurity (MSE) = 8.617283950617283
#   Samples = 594
#   Value = [[2.22222222]]
# Node 1082:
#   Impurity (MSE) = 15.429678587596198
#   Samples = 235
#   Value = [[3.35744681]]
# Node 1083:
#   Impurity (MSE) = 4.057760768956925
#   Samples = 106
#   Value = [[1.74528302]]
# Node 1084:
#   Impurity (MSE) = 20.883480560062495
#   Samples = 129
#   Value = [[4.68217054]]
# Node 1085:
#   Impurity (MSE) = 2.762098369814014
#   Samples = 359
#   Value = [[1.47910864]]
# Node 1086:
#   Impurity (MSE) = 1.2001387443635105
#   Samples = 186
#   Value = [[1.06451613]]
# Node 1087:
#   Impurity (MSE) = 4.057937117845568
#   Samples = 173
#   Value = [[1.92485549]]
# Node 1088:
#   Impurity (MSE) = 23.97227323742476
#   Samples = 198
#   Value = [[3.79292929]]
# Node 1089:
#   Impurity (MSE) = 41.64262343842951
#   Samples = 82
#   Value = [[5.93902439]]
# Node 1090:
#   Impurity (MSE) = 13.378694703431858
#   Samples = 71
#   Value = [[4.33802817]]
# Node 1091:
#   Impurity (MSE) = 1.688888888888889
#   Samples = 30
#   Value = [[1.33333333]]
# Node 1092:
#   Impurity (MSE) = 1.1404958677685961
#   Samples = 11
#   Value = [[2.63636364]]
# Node 1093:
#   Impurity (MSE) = 0.45429362880886426
#   Samples = 19
#   Value = [[0.57894737]]
# Node 1094:
#   Impurity (MSE) = 10.492563950029748
#   Samples = 41
#   Value = [[6.53658537]]
# Node 1095:
#   Impurity (MSE) = 3.339999999999989
#   Samples = 20
#   Value = [[9.4]]
# Node 1096:
#   Impurity (MSE) = 2.058956916099776
#   Samples = 21
#   Value = [[3.80952381]]
# Node 1097:
#   Impurity (MSE) = 100.74380165289256
#   Samples = 11
#   Value = [[16.27272727]]
# Node 1098:
#   Impurity (MSE) = 1.2222222222222285
#   Samples = 6
#   Value = [[8.66666667]]
# Node 1099:
#   Impurity (MSE) = 67.44000000000005
#   Samples = 5
#   Value = [[25.4]]
# Node 1100:
#   Impurity (MSE) = 5.923900118906064
#   Samples = 116
#   Value = [[2.27586207]]
# Node 1101:
#   Impurity (MSE) = 12.710562414266116
#   Samples = 27
#   Value = [[3.74074074]]
# Node 1102:
#   Impurity (MSE) = 5.7475
#   Samples = 20
#   Value = [[2.05]]
# Node 1103:
#   Impurity (MSE) = 6.153846153846153
#   Samples = 13
#   Value = [[3.]]
# Node 1104:
#   Impurity (MSE) = 0.20408163265306123
#   Samples = 7
#   Value = [[0.28571429]]
# Node 1105:
#   Impurity (MSE) = 1.1020408163265358
#   Samples = 7
#   Value = [[8.57142857]]
# Node 1106:
#   Impurity (MSE) = 3.0165383158692087
#   Samples = 89
#   Value = [[1.83146067]]
# Node 1107:
#   Impurity (MSE) = 1.5288888888888892
#   Samples = 30
#   Value = [[0.73333333]]
# Node 1108:
#   Impurity (MSE) = 2.734375
#   Samples = 8
#   Value = [[1.625]]
# Node 1109:
#   Impurity (MSE) = 0.6962809917355371
#   Samples = 22
#   Value = [[0.40909091]]
# Node 1110:
#   Impurity (MSE) = 2.8480321746624533
#   Samples = 59
#   Value = [[2.38983051]]
# Node 1111:
#   Impurity (MSE) = 0.6597222222222223
#   Samples = 24
#   Value = [[1.58333333]]
# Node 1112:
#   Impurity (MSE) = 3.5967346938775506
#   Samples = 35
#   Value = [[2.94285714]]
# Node 1113:
#   Impurity (MSE) = 279.44888888888886
#   Samples = 15
#   Value = [[10.13333333]]
# Node 1114:
#   Impurity (MSE) = 463.25
#   Samples = 6
#   Value = [[21.5]]
# Node 1115:
#   Impurity (MSE) = 13.358024691358025
#   Samples = 9
#   Value = [[2.55555556]]
# Node 1116:
#   Impurity (MSE) = 1.2786787254402114
#   Samples = 631
#   Value = [[0.12044374]]
# Node 1117:
#   Impurity (MSE) = 0.6789321863917868
#   Samples = 622
#   Value = [[0.07717042]]
# Node 1118:
#   Impurity (MSE) = 4.2857142857142865
#   Samples = 7
#   Value = [[3.]]
# Node 1119:
#   Impurity (MSE) = 0.5395359904818561
#   Samples = 615
#   Value = [[0.04390244]]
# Node 1120:
#   Impurity (MSE) = 0.014946722441980496
#   Samples = 593
#   Value = [[0.01517707]]
# Node 1121:
#   Impurity (MSE) = 0.12244897959183676
#   Samples = 7
#   Value = [[0.85714286]]
# Node 1122:
#   Impurity (MSE) = 0.005093245116425352
#   Samples = 586
#   Value = [[0.00511945]]
# Node 1123:
#   Impurity (MSE) = 0.0020533793967721726
#   Samples = 486
#   Value = [[0.00205761]]
# Node 1124:
#   Impurity (MSE) = 0.0
#   Samples = 417
#   Value = [[0.]]
# Node 1125:
#   Impurity (MSE) = 0.014282713715605966
#   Samples = 69
#   Value = [[0.01449275]]
# Node 1126:
#   Impurity (MSE) = 0.0196
#   Samples = 100
#   Value = [[0.02]]
# Node 1127:
#   Impurity (MSE) = 0.045351473922902494
#   Samples = 42
#   Value = [[0.04761905]]
# Node 1128:
#   Impurity (MSE) = 0.0
#   Samples = 58
#   Value = [[0.]]
# Node 1129:
#   Impurity (MSE) = 14.057851239669422
#   Samples = 22
#   Value = [[0.81818182]]
# Node 1130:
#   Impurity (MSE) = 45.0
#   Samples = 6
#   Value = [[3.]]
# Node 1131:
#   Impurity (MSE) = 0.0
#   Samples = 16
#   Value = [[0.]]
# Node 1132:
#   Impurity (MSE) = 33.65432098765432
#   Samples = 9
#   Value = [[3.11111111]]

# %%
cleaned_features.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 cleaned_features.describe()
#
# NameError: name 'cleaned_features' is not defined

# %%
print(cleaned_features.describe())
print(cleaned_target.describe())
# Out:
#             ID_Base  ID_Timestamp   stop_number  starting_station_IBNR  \
# count  92372.000000  9.237200e+04  92372.000000           9.237200e+04
# mean    2334.743624  2.407109e+09      5.845581           8.012398e+06
# std     1327.437959  2.122525e+04      5.012597           2.565280e+04
# min        0.000000  2.407040e+09      1.000000           8.000014e+06
# 25%     1223.000000  2.407092e+09      2.000000           8.000661e+06
# 50%     2329.000000  2.407111e+09      4.000000           8.002806e+06
# 75%     3484.000000  2.407130e+09      7.000000           8.006714e+06
# max     4677.000000  2.407142e+09     32.000000           8.089474e+06
#
#                IBNR          long           lat  info_present  \
# count  9.237200e+04  92372.000000  92372.000000  92372.000000
# mean   7.950999e+06      8.827858     49.206997      0.298619
# std    6.876468e+05      2.880577      9.857873      0.457655
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    8.000683e+06      6.975001     49.813426      0.000000
# 50%    8.002828e+06      8.649481     51.202058      0.000000
# 75%    8.005910e+06     10.988291     52.373607      1.000000
# max    8.098549e+06     14.979080     54.888814      1.000000
#
#        last_station_encoded  arrival_year  arrival_month   arrival_day  \
# count          92372.000000       88896.0        88896.0  88896.000000
# mean             497.488503        2024.0            7.0     10.904990
# std              300.380397           0.0            0.0      1.977623
# min                0.000000        2024.0            7.0      8.000000
# 25%              250.000000        2024.0            7.0      9.000000
# 50%              489.000000        2024.0            7.0     11.000000
# 75%              761.000000        2024.0            7.0     13.000000
# max             1036.000000        2024.0            7.0     14.000000
#
#        arrival_hour  arrival_minute  departure_year  departure_month  \
# count  88896.000000    88896.000000         88896.0          88896.0
# mean      13.195678       29.665418          2024.0              7.0
# std        5.713547       17.030966             0.0              0.0
# min        0.000000        0.000000          2024.0              7.0
# 25%        9.000000       15.000000          2024.0              7.0
# 50%       14.000000       29.000000          2024.0              7.0
# 75%       18.000000       44.000000          2024.0              7.0
# max       23.000000       59.000000          2024.0              7.0
#
#        departure_day  departure_hour  departure_minute
# count   88896.000000    88896.000000      88896.000000
# mean       10.905283       13.210392         29.307168
# std         1.977563        5.718438         17.040249
# min         8.000000        0.000000          0.000000
# 25%         9.000000        9.000000         15.000000
# 50%        11.000000       14.000000         29.000000
# 75%        13.000000       18.000000         44.000000
# max        14.000000       23.000000         59.000000
# count    92372.000000
# mean         1.305883
# std          4.070284
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max        133.000000
# Name: arrival_delay_m, dtype: float64

# %%
cleaned_features
# Out:
#          ID_Base  ID_Timestamp  stop_number  starting_station_IBNR       IBNR  \
# 12190       1172    2407130634            2                8000014  8004965.0
# 12192       1172    2407140634            2                8000014  8004965.0
# 12227        684    2407081034            2                8000014  8004965.0
# 12229        684    2407091034            2                8000014  8004965.0
# 12231        684    2407111034            2                8000014  8004965.0
# ...          ...           ...          ...                    ...        ...
# 2792541     2777    2407120110            1                8089131  8089015.0
# 2792542     2398    2407120010            1                8089131  8089015.0
# 2792545     3123    2407100231            2                8089131  8089116.0
# 2792547     3123    2407110231            2                8089131  8089116.0
# 2810789     3709    2407130500            2                8089474  8089106.0
#
#               long        lat  info_present  last_station_encoded  \
# 12190     9.606100  47.784481             0                   834
# 12192     9.606100  47.784481             0                   834
# 12227     9.606100  47.784481             1                   834
# 12229     9.606100  47.784481             0                   834
# 12231     9.606100  47.784481             0                   834
# ...            ...        ...           ...                   ...
# 2792541   0.000000   0.000000             0                    78
# 2792542   0.000000   0.000000             0                    78
# 2792545  13.344253  52.536250             0                   107
# 2792547  13.344253  52.536250             0                   107
# 2810789  13.342197  52.478084             0                    84
#
#          arrival_year  arrival_month  arrival_day  arrival_hour  \
# 12190          2024.0            7.0         13.0           6.0
# 12192          2024.0            7.0         14.0           6.0
# 12227          2024.0            7.0          8.0          10.0
# 12229          2024.0            7.0          9.0          10.0
# 12231          2024.0            7.0         11.0          10.0
# ...               ...            ...          ...           ...
# 2792541           NaN            NaN          NaN           NaN
# 2792542           NaN            NaN          NaN           NaN
# 2792545        2024.0            7.0         10.0           2.0
# 2792547        2024.0            7.0         11.0           2.0
# 2810789        2024.0            7.0         13.0           5.0
#
#          arrival_minute  departure_year  departure_month  departure_day  \
# 12190              45.0          2024.0              7.0           13.0
# 12192              45.0          2024.0              7.0           14.0
# 12227              45.0          2024.0              7.0            8.0
# 12229              45.0          2024.0              7.0            9.0
# 12231              45.0          2024.0              7.0           11.0
# ...                 ...             ...              ...            ...
# 2792541             NaN             NaN              NaN            NaN
# 2792542             NaN             NaN              NaN            NaN
# 2792545            32.0          2024.0              7.0           10.0
# 2792547            32.0          2024.0              7.0           11.0
# 2810789             1.0          2024.0              7.0           13.0
#
#          departure_hour  departure_minute
# 12190               6.0              46.0
# 12192               6.0              46.0
# 12227              10.0              46.0
# 12229              10.0              46.0
# 12231              10.0              46.0
# ...                 ...               ...
# 2792541             NaN               NaN
# 2792542             NaN               NaN
# 2792545             2.0              33.0
# 2792547             2.0              33.0
# 2810789             5.0               2.0
#
# [92372 rows x 19 columns]
