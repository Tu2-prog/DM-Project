# %% [markdown]
# ## Data Loading
# This section covers the initial loading of the dataset and importing the necessary libraries.

# %%
import pandas as pd

# %%
train_rides_df = pd.read_csv('DBtrainrides.csv')

# %% [markdown]
# ### Previewing the Data
# Take a quick look at the first few rows of the dataset to understand its structure.

# %%
# Display the first few rows of the train rides DataFrame
train_rides_df.head()
# Out:
#                                   ID line  \
# 0  1573967790757085557-2407072312-14   20
# 1    349781417030375472-2407080017-1   18
# 2  7157250219775883918-2407072120-25    1
# 3    349781417030375472-2407080017-2   18
# 4   1983158592123451570-2407080010-3   33
#
#                                                 path   eva_nr  category  \
# 0  Stolberg(Rheinl)Hbf Gl.44|Eschweiler-St.Jöris|...  8000001         2
# 1                                                NaN  8000001         2
# 2  Hamm(Westf)Hbf|Kamen|Kamen-Methler|Dortmund-Ku...  8000406         4
# 3                                         Aachen Hbf  8000404         5
# 4                            Herzogenrath|Kohlscheid  8000404         5
#
#              station                state    city    zip      long        lat  \
# 0         Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.767800
# 1         Aachen Hbf  Nordrhein-Westfalen  Aachen  52064  6.091499  50.767800
# 2  Aachen-Rothe Erde  Nordrhein-Westfalen  Aachen  52066  6.116475  50.770202
# 3        Aachen West  Nordrhein-Westfalen  Aachen  52072  6.070715  50.780360
# 4        Aachen West  Nordrhein-Westfalen  Aachen  52072  6.070715  50.780360
#
#           arrival_plan       departure_plan       arrival_change  \
# 0  2024-07-08 00:00:00  2024-07-08 00:01:00  2024-07-08 00:03:00
# 1                  NaN  2024-07-08 00:17:00                  NaN
# 2  2024-07-08 00:03:00  2024-07-08 00:04:00  2024-07-08 00:03:00
# 3  2024-07-08 00:20:00  2024-07-08 00:21:00                  NaN
# 4  2024-07-08 00:20:00  2024-07-08 00:21:00  2024-07-08 00:20:00
#
#       departure_change  arrival_delay_m  departure_delay_m info  \
# 0  2024-07-08 00:04:00                3                  3  NaN
# 1                  NaN                0                  0  NaN
# 2  2024-07-08 00:04:00                0                  0  NaN
# 3                  NaN                0                  0  NaN
# 4  2024-07-08 00:21:00                0                  0  NaN
#
#   arrival_delay_check departure_delay_check
# 0             on_time               on_time
# 1             on_time               on_time
# 2             on_time               on_time
# 3             on_time               on_time
# 4             on_time               on_time

# %% [markdown]
# ## Data Cleaning
# In this section, we clean and preprocess the data to prepare it for analysis.

# %%
# Count missing values to understand data quality
train_rides_df.count()
# Out:
# ID                       2061357
# line                     2061357
# path                     1850002
# eva_nr                   2061357
# category                 2061357
# station                  2061357
# state                    2061357
# city                     2061357
# zip                      2061357
# long                     2061357
# lat                      2061357
# arrival_plan             1850002
# departure_plan           2061357
# arrival_change           1585727
# departure_change         1721431
# arrival_delay_m          2061357
# departure_delay_m        2061357
# info                      645341
# arrival_delay_check      2061357
# departure_delay_check    2061357
# dtype: int64

# %%
# Group by 'zip' to understand distribution
zip_df = train_rides_df.groupby('zip').size().reset_index(name='count')
zip_df
# Out:
#         zip  count
# 0      1067   2458
# 1      1069   2045
# 2      1097   3305
# 3      1109   1800
# 4      1127    597
# ...     ...    ...
# 1646  99817    453
# 1647  99867    494
# 1648  99880    424
# 1649  99947    453
# 1650  99974    421
#
# [1651 rows x 2 columns]

# %% [markdown]
# ### Station Mapping
# We create a mapping of stations to understand how often each 'eva_nr' appears in the dataset.

# %%
# Step 2: Create a new DataFrame with a count of how often each 'eva_nr' is mentioned
station_mapping_df = train_rides_df['eva_nr'].value_counts().reset_index()
station_mapping_df.columns = ['eva_nr', 'count']
station_mapping_df
# Out:
#        eva_nr  count
# 0     8004128   8732
# 1     8089047   8312
# 2     8000262   7814
# 3     8004132   7598
# 4     8004131   7382
# ...       ...    ...
# 1991  8007768     95
# 1992  8005644     74
# 1993  8005543     49
# 1994  8010035      5
# 1995  8010241      5
#
# [1996 rows x 2 columns]

# %%
# Count number of unique 'eva_nr' to understand the spread across different stations
station_mapping_df.count()
# Out:
# eva_nr    1996
# count     1996
# dtype: int64

# %% [markdown]
# ### Station Analysis
# We now perform grouping and transformation operations to extract insights from the station-related data.

# %%
# Fill missing values in 'path' with empty strings
train_rides_df['path'] = train_rides_df['path'].fillna('')

# Split the 'path' into individual stations by '|', creating a list in each row
train_rides_df = train_rides_df.assign(current_station=train_rides_df['path'].str.split('|'))

# Explode the 'current_station' column to create individual rows for each station
split_stations_df = train_rides_df.explode('current_station').drop(columns=['path'])

# Add a counter to keep track of the sequence of stops within each path
split_stations_df['stop_number'] = split_stations_df.groupby('ID').cumcount() + 1

# Display the result
split_stations_df.head()
# Out:
#                                   ID line   eva_nr  category     station  \
# 0  1573967790757085557-2407072312-14   20  8000001         2  Aachen Hbf
# 0  1573967790757085557-2407072312-14   20  8000001         2  Aachen Hbf
# 0  1573967790757085557-2407072312-14   20  8000001         2  Aachen Hbf
# 0  1573967790757085557-2407072312-14   20  8000001         2  Aachen Hbf
# 0  1573967790757085557-2407072312-14   20  8000001         2  Aachen Hbf
#
#                  state    city    zip      long      lat  ...  \
# 0  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678  ...
# 0  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678  ...
# 0  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678  ...
# 0  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678  ...
# 0  Nordrhein-Westfalen  Aachen  52064  6.091499  50.7678  ...
#
#         departure_plan       arrival_change     departure_change  \
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
#
#   arrival_delay_m  departure_delay_m  info arrival_delay_check  \
# 0               3                  3   NaN             on_time
# 0               3                  3   NaN             on_time
# 0               3                  3   NaN             on_time
# 0               3                  3   NaN             on_time
# 0               3                  3   NaN             on_time
#
#   departure_delay_check            current_station stop_number
# 0               on_time  Stolberg(Rheinl)Hbf Gl.44           1
# 0               on_time        Eschweiler-St.Jöris           2
# 0               on_time         Alsdorf Poststraße           3
# 0               on_time          Alsdorf-Mariadorf           4
# 0               on_time        Alsdorf-Kellersberg           5
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Merging Station Data
# We will now merge the station data to map identifiers to each station.

# %%
# # Perform the merge operation to map stations and ensure the station names match by stripping leading/trailing spaces
# split_stations_df['current_station'] = split_stations_df['current_station'].str.strip()
# 
# # Create an internal station mapping DataFrame
# station_internal_eva_mapping_df = split_stations_df.merge(
#     station_mapping_df, on='eva_nr', how='left'
# )
# station_internal_eva_mapping_df

# %% [markdown]
# ## Data Visualisation
# In this section, we create visualisations to help us better understand the data.

# %% [markdown]
# The map above shows the geographic locations of train stations using latitude and longitude data.

# %% [markdown]
# ## Summary and Insights
# This section summarises the key insights derived from the analysis and visualisation.

# %%
station_mapping_df.count()
# Out:
# eva_nr    1996
# count     1996
# dtype: int64

# %% [markdown]
# what is the average number of stations per category? go check the 'category' column

# %%
# station_internal_eva_mapping_df.head(1000)

# %%
eva_df = pd.read_csv('stations.csv')
eva_df
# Out:
#               Station Name     IBNR
# 0               Aachen Hbf  8000001
# 1            Aachen Schanz  8070704
# 2           Aachen Süd(Gr)  8000403
# 3              Aachen West  8000404
# 4        Aachen-Rothe Erde  8000406
# ...                    ...      ...
# 7662  Zwingenberg(Bergstr)  8006687
# 7663               Zwönitz  8013435
# 7664                 Zwota  8013437
# 7665      Zwota-Zechenbach  8013436
# 7666             Zwotental  8010398
#
# [7667 rows x 2 columns]

# %%
# Entferne mögliche führende oder nachgestellte Leerzeichen und setze auf Kleinbuchstaben
split_stations_df['current_station'] = split_stations_df['current_station'].str.strip().str.lower()
eva_df['Station Name'] = eva_df['Station Name'].str.strip().str.lower()

# Updated merge using 'station' instead of 'Station Name'
station_external_eva_mapping_df = split_stations_df.merge(
    eva_df, 
    how='left', 
    left_on='current_station', 
    right_on='Station Name'
)

# %%
station_external_eva_mapping_df
# Out:
#                                          ID line   eva_nr  category  \
# 0         1573967790757085557-2407072312-14   20  8000001         2
# 1         1573967790757085557-2407072312-14   20  8000001         2
# 2         1573967790757085557-2407072312-14   20  8000001         2
# 3         1573967790757085557-2407072312-14   20  8000001         2
# 4         1573967790757085557-2407072312-14   20  8000001         2
# ...                                     ...  ...      ...       ...
# 19785712   3370285438001482281-2407142234-7    8  8003775         5
# 19785713  -8774053210575864323-2407142305-3   80  8003775         5
# 19785714  -8774053210575864323-2407142305-3   80  8003775         5
# 19785715  -1537118689903044118-2407142354-1   11  8001580         4
# 19785716   2862161729195150146-2407142324-1   11  8001580         4
#
#                                 station                state        city  \
# 0                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 1                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 2                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 3                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 4                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# ...                                 ...                  ...         ...
# 19785712                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785713                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785714                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785715  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
# 19785716  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
#
#             zip       long        lat  ...     departure_change  \
# 0         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# 1         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# 2         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# 3         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# 4         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# ...         ...        ...        ...  ...                  ...
# 19785712  23560  10.629500  53.836800  ...  2024-07-14 23:12:00
# 19785713  23560  10.629500  53.836800  ...  2024-07-14 23:18:00
# 19785714  23560  10.629500  53.836800  ...  2024-07-14 23:18:00
# 19785715  40474   6.766979  51.278517  ...                  NaN
# 19785716  40474   6.766979  51.278517  ...  2024-07-14 23:24:00
#
#          arrival_delay_m departure_delay_m  \
# 0                      3                 3
# 1                      3                 3
# 2                      3                 3
# 3                      3                 3
# 4                      3                 3
# ...                  ...               ...
# 19785712               1                 1
# 19785713               0                 0
# 19785714               0                 0
# 19785715               0                 0
# 19785716               0                 0
#
#                                         info  arrival_delay_check  \
# 0                                        NaN              on_time
# 1                                        NaN              on_time
# 2                                        NaN              on_time
# 3                                        NaN              on_time
# 4                                        NaN              on_time
# ...                                      ...                  ...
# 19785712                         Information              on_time
# 19785713                         Information              on_time
# 19785714                         Information              on_time
# 19785715  Information. (Quelle: zuginfo.nrw)              on_time
# 19785716  Information. (Quelle: zuginfo.nrw)              on_time
#
#           departure_delay_check            current_station stop_number  \
# 0                       on_time  stolberg(rheinl)hbf gl.44           1
# 1                       on_time        eschweiler-st.jöris           2
# 2                       on_time         alsdorf poststraße           3
# 3                       on_time          alsdorf-mariadorf           4
# 4                       on_time        alsdorf-kellersberg           5
# ...                         ...                        ...         ...
# 19785712                on_time                 lübeck hbf           6
# 19785713                on_time               bad oldesloe           1
# 19785714                on_time            reinfeld(holst)           2
# 19785715                on_time                                      1
# 19785716                on_time                                      1
#
#                  Station Name       IBNR
# 0                         NaN        NaN
# 1         eschweiler-st.jöris  8001917.0
# 2          alsdorf poststraße  8000510.0
# 3           alsdorf-mariadorf  8000527.0
# 4         alsdorf-kellersberg  8000521.0
# ...                       ...        ...
# 19785712           lübeck hbf  8000237.0
# 19785713         bad oldesloe  8000023.0
# 19785714      reinfeld(holst)  8005019.0
# 19785715                  NaN        NaN
# 19785716                  NaN        NaN
#
# [19785717 rows x 23 columns]

# %%
station_external_eva_mapping_df.count()
# Out:
# ID                       19785717
# line                     19785717
# eva_nr                   19785717
# category                 19785717
# station                  19785717
# state                    19785717
# city                     19785717
# zip                      19785717
# long                     19785717
# lat                      19785717
# arrival_plan             19574362
# departure_plan           19785717
# arrival_change           18020530
# departure_change         18039856
# arrival_delay_m          19785717
# departure_delay_m        19785717
# info                      6933524
# arrival_delay_check      19785717
# departure_delay_check    19785717
# current_station          19785717
# stop_number              19785717
# Station Name             18475441
# IBNR                     18475441
# dtype: int64

# %%
# Count where 'Station Name' is NaN and 'current_station' is not NaN
count_nan_station_name = station_external_eva_mapping_df[
    (station_external_eva_mapping_df['Station Name'].isna()) & 
    (station_external_eva_mapping_df['current_station'].notna())
].shape[0]
count_nan_station_name
# Out:
# 1310276

# %%
station_external_eva_mapping_df.columns
# Out:
# Index(['ID', 'line', 'eva_nr', 'category', 'station', 'state', 'city', 'zip',
#        'long', 'lat', 'arrival_plan', 'departure_plan', 'arrival_change',
#        'departure_change', 'arrival_delay_m', 'departure_delay_m', 'info',
#        'arrival_delay_check', 'departure_delay_check', 'current_station',
#        'stop_number', 'Station Name', 'IBNR'],
#       dtype='object')

# %%
# Convert empty strings back to NaN in 'path' column
station_external_eva_mapping_df['current_station'] = station_external_eva_mapping_df['current_station'].replace('', pd.NA)

# Count rows where 'station' is NaN
nan_station_count = station_external_eva_mapping_df['current_station'].isna().sum()
print(f"Number of rows with NaN station names: {nan_station_count}")
# Out:
# Number of rows with NaN station names: 211355

# %%
# Count rows where 'station' is NaN
nan_station_count = station_external_eva_mapping_df['Station Name'].isna().sum()
print(f"Number of rows with NaN station names: {nan_station_count}")
# Out:
# Number of rows with NaN station names: 1310276

# %%
filtered_df = station_external_eva_mapping_df[station_external_eva_mapping_df['Station Name'].isna()]

# %%
filtered_df
# Out:
#                                           ID  line   eva_nr  category  \
# 0          1573967790757085557-2407072312-14    20  8000001         2
# 13           349781417030375472-2407080017-1    18  8000001         2
# 14         7157250219775883918-2407072120-25     1  8000406         4
# 47        -2100556839975301087-2407072307-13    18  8000404         5
# 48        -2100556839975301087-2407072307-13    18  8000404         5
# ...                                      ...   ...      ...       ...
# 19785699  -4498532330426324655-2407142201-14  RE18  8003105         5
# 19785701   -5558360799253050120-2407142310-4  RE18  8003105         5
# 19785711    3370285438001482281-2407142234-7     8  8003775         5
# 19785715   -1537118689903044118-2407142354-1    11  8001580         4
# 19785716    2862161729195150146-2407142324-1    11  8001580         4
#
#                                 station                state        city  \
# 0                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 13                           Aachen Hbf  Nordrhein-Westfalen      Aachen
# 14                    Aachen-Rothe Erde  Nordrhein-Westfalen      Aachen
# 47                          Aachen West  Nordrhein-Westfalen      Aachen
# 48                          Aachen West  Nordrhein-Westfalen      Aachen
# ...                                 ...                  ...         ...
# 19785699                      Jaderberg        Niedersachsen   Jaderberg
# 19785701                      Jaderberg        Niedersachsen   Jaderberg
# 19785711                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785715  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
# 19785716  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
#
#             zip       long        lat  ...     departure_change  \
# 0         52064   6.091499  50.767800  ...  2024-07-08 00:04:00
# 13        52064   6.091499  50.767800  ...                  NaN
# 14        52066   6.116475  50.770202  ...  2024-07-08 00:04:00
# 47        52072   6.070715  50.780360  ...  2024-07-08 00:41:00
# 48        52072   6.070715  50.780360  ...  2024-07-08 00:41:00
# ...         ...        ...        ...  ...                  ...
# 19785699  26349   8.184538  53.344878  ...  2024-07-14 23:56:00
# 19785701  26349   8.184538  53.344878  ...  2024-07-14 23:33:00
# 19785711  23560  10.629500  53.836800  ...  2024-07-14 23:12:00
# 19785715  40474   6.766979  51.278517  ...                  NaN
# 19785716  40474   6.766979  51.278517  ...  2024-07-14 23:24:00
#
#          arrival_delay_m departure_delay_m  \
# 0                      3                 3
# 13                     0                 0
# 14                     0                 0
# 47                     0                 0
# 48                     0                 0
# ...                  ...               ...
# 19785699               0                 0
# 19785701               0                 0
# 19785711               1                 1
# 19785715               0                 0
# 19785716               0                 0
#
#                                         info  arrival_delay_check  \
# 0                                        NaN              on_time
# 13                                       NaN              on_time
# 14                                       NaN              on_time
# 47                                       NaN              on_time
# 48                                       NaN              on_time
# ...                                      ...                  ...
# 19785699                         Bauarbeiten              on_time
# 19785701                         Bauarbeiten              on_time
# 19785711                         Information              on_time
# 19785715  Information. (Quelle: zuginfo.nrw)              on_time
# 19785716  Information. (Quelle: zuginfo.nrw)              on_time
#
#           departure_delay_check            current_station stop_number  \
# 0                       on_time  stolberg(rheinl)hbf gl.44           1
# 13                      on_time                       <NA>           1
# 14                      on_time             hamm(westf)hbf           1
# 47                      on_time           liège-guillemins           1
# 48                      on_time                   bressoux           2
# ...                         ...                        ...         ...
# 19785699                on_time         oldenburg(oldb)hbf          12
# 19785701                on_time              wilhelmshaven           1
# 19785711                on_time    lübeck-dänischburg ikea           5
# 19785715                on_time                       <NA>           1
# 19785716                on_time                       <NA>           1
#
#          Station Name IBNR
# 0                 NaN  NaN
# 13                NaN  NaN
# 14                NaN  NaN
# 47                NaN  NaN
# 48                NaN  NaN
# ...               ...  ...
# 19785699          NaN  NaN
# 19785701          NaN  NaN
# 19785711          NaN  NaN
# 19785715          NaN  NaN
# 19785716          NaN  NaN
#
# [1310276 rows x 23 columns]

# %%
eva_v2_df = pd.read_csv('stations_v2.csv')
eva_v2_df['Station Name'] = eva_df['Station Name'].str.strip().str.lower()
eva_v2_df
# Out:
#          IBNR       Station Name
# 0     8000001         aachen hbf
# 1     8000001      aachen schanz
# 2     8000001     aachen süd(gr)
# 3     8000001        aachen west
# 4     8000001  aachen-rothe erde
# ...       ...                ...
# 9128  8098553                NaN
# 9129  8098555                NaN
# 9130  8099503                NaN
# 9131  8099506                NaN
# 9132  8099507                NaN
#
# [9133 rows x 2 columns]

# %%
# Updated merge using 'station' instead of 'Station Name'
station_external_eva_mapping_v2_df = split_stations_df.merge(
    eva_v2_df, 
    how='left', 
    left_on='current_station', 
    right_on='Station Name'
)

# %%
# Convert empty strings in the 'current_station' column to NaN values
station_external_eva_mapping_v2_df['current_station'] = station_external_eva_mapping_v2_df['current_station'].replace('', pd.NA)

# Count and display the number of rows with NaN values in the 'current_station' column
nan_current_station_count = station_external_eva_mapping_v2_df['current_station'].isna().sum()
print(f"Number of rows with NaN values in 'current_station': {nan_current_station_count}")

# Count and display the number of rows with NaN values in the 'Station Name' column
nan_station_name_count = station_external_eva_mapping_v2_df['Station Name'].isna().sum()
print(f"Number of rows with NaN values in 'Station Name': {nan_station_name_count}")
# Out:
# Number of rows with NaN values in 'current_station': 211355
# Number of rows with NaN values in 'Station Name': 1310276

# %%
filtered_v2_df = station_external_eva_mapping_df[station_external_eva_mapping_df['Station Name'].isna() & station_external_eva_mapping_df['current_station'].notna()]
filtered_v2_df
# Out:
#                                           ID  line   eva_nr  category  \
# 0          1573967790757085557-2407072312-14    20  8000001         2
# 14         7157250219775883918-2407072120-25     1  8000406         4
# 47        -2100556839975301087-2407072307-13    18  8000404         5
# 48        -2100556839975301087-2407072307-13    18  8000404         5
# 49        -2100556839975301087-2407072307-13    18  8000404         5
# ...                                      ...   ...      ...       ...
# 19785381    5391302266099657590-2407142320-8    68  8006283         5
# 19785385    5391302266099657590-2407142320-8    68  8006283         5
# 19785699  -4498532330426324655-2407142201-14  RE18  8003105         5
# 19785701   -5558360799253050120-2407142310-4  RE18  8003105         5
# 19785711    3370285438001482281-2407142234-7     8  8003775         5
#
#                     station                state       city    zip       long  \
# 0                Aachen Hbf  Nordrhein-Westfalen     Aachen  52064   6.091499
# 14        Aachen-Rothe Erde  Nordrhein-Westfalen     Aachen  52066   6.116475
# 47              Aachen West  Nordrhein-Westfalen     Aachen  52072   6.070715
# 48              Aachen West  Nordrhein-Westfalen     Aachen  52072   6.070715
# 49              Aachen West  Nordrhein-Westfalen     Aachen  52072   6.070715
# ...                     ...                  ...        ...    ...        ...
# 19785381  Weinheim-Sulzbach    Baden-Württemberg   Weinheim  69469   8.656360
# 19785385  Weinheim-Sulzbach    Baden-Württemberg   Weinheim  69469   8.656360
# 19785699          Jaderberg        Niedersachsen  Jaderberg  26349   8.184538
# 19785701          Jaderberg        Niedersachsen  Jaderberg  26349   8.184538
# 19785711    Lübeck-Moisling   Schleswig-Holstein     Lübeck  23560  10.629500
#
#                 lat  ...     departure_change arrival_delay_m  \
# 0         50.767800  ...  2024-07-08 00:04:00               3
# 14        50.770202  ...  2024-07-08 00:04:00               0
# 47        50.780360  ...  2024-07-08 00:41:00               0
# 48        50.780360  ...  2024-07-08 00:41:00               0
# 49        50.780360  ...  2024-07-08 00:41:00               0
# ...             ...  ...                  ...             ...
# 19785381  49.575800  ...  2024-07-14 23:51:00               0
# 19785385  49.575800  ...  2024-07-14 23:51:00               0
# 19785699  53.344878  ...  2024-07-14 23:56:00               0
# 19785701  53.344878  ...  2024-07-14 23:33:00               0
# 19785711  53.836800  ...  2024-07-14 23:12:00               1
#
#          departure_delay_m         info  arrival_delay_check  \
# 0                        3          NaN              on_time
# 14                       0          NaN              on_time
# 47                       0          NaN              on_time
# 48                       0          NaN              on_time
# 49                       0          NaN              on_time
# ...                    ...          ...                  ...
# 19785381                 1  Information              on_time
# 19785385                 1  Information              on_time
# 19785699                 0  Bauarbeiten              on_time
# 19785701                 0  Bauarbeiten              on_time
# 19785711                 1  Information              on_time
#
#           departure_delay_check             current_station stop_number  \
# 0                       on_time   stolberg(rheinl)hbf gl.44           1
# 14                      on_time              hamm(westf)hbf           1
# 47                      on_time            liège-guillemins           1
# 48                      on_time                    bressoux           2
# 49                      on_time                        vise           3
# ...                         ...                         ...         ...
# 19785381                on_time  neu-edingen/friedrichsfeld           3
# 19785385                on_time        weinheim(bergstr)hbf           7
# 19785699                on_time          oldenburg(oldb)hbf          12
# 19785701                on_time               wilhelmshaven           1
# 19785711                on_time     lübeck-dänischburg ikea           5
#
#          Station Name IBNR
# 0                 NaN  NaN
# 14                NaN  NaN
# 47                NaN  NaN
# 48                NaN  NaN
# 49                NaN  NaN
# ...               ...  ...
# 19785381          NaN  NaN
# 19785385          NaN  NaN
# 19785699          NaN  NaN
# 19785701          NaN  NaN
# 19785711          NaN  NaN
#
# [1098921 rows x 23 columns]

# %%
station_external_eva_mapping_v2_df
# Out:
#                                          ID line   eva_nr  category  \
# 0         1573967790757085557-2407072312-14   20  8000001         2
# 1         1573967790757085557-2407072312-14   20  8000001         2
# 2         1573967790757085557-2407072312-14   20  8000001         2
# 3         1573967790757085557-2407072312-14   20  8000001         2
# 4         1573967790757085557-2407072312-14   20  8000001         2
# ...                                     ...  ...      ...       ...
# 19785712   3370285438001482281-2407142234-7    8  8003775         5
# 19785713  -8774053210575864323-2407142305-3   80  8003775         5
# 19785714  -8774053210575864323-2407142305-3   80  8003775         5
# 19785715  -1537118689903044118-2407142354-1   11  8001580         4
# 19785716   2862161729195150146-2407142324-1   11  8001580         4
#
#                                 station                state        city  \
# 0                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 1                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 2                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 3                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# 4                            Aachen Hbf  Nordrhein-Westfalen      Aachen
# ...                                 ...                  ...         ...
# 19785712                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785713                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785714                Lübeck-Moisling   Schleswig-Holstein      Lübeck
# 19785715  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
# 19785716  Düsseldorf Flughafen Terminal  Nordrhein-Westfalen  Düsseldorf
#
#             zip       long        lat  ... departure_delay_m  \
# 0         52064   6.091499  50.767800  ...                 3
# 1         52064   6.091499  50.767800  ...                 3
# 2         52064   6.091499  50.767800  ...                 3
# 3         52064   6.091499  50.767800  ...                 3
# 4         52064   6.091499  50.767800  ...                 3
# ...         ...        ...        ...  ...               ...
# 19785712  23560  10.629500  53.836800  ...                 1
# 19785713  23560  10.629500  53.836800  ...                 0
# 19785714  23560  10.629500  53.836800  ...                 0
# 19785715  40474   6.766979  51.278517  ...                 0
# 19785716  40474   6.766979  51.278517  ...                 0
#
#                                         info arrival_delay_check  \
# 0                                        NaN             on_time
# 1                                        NaN             on_time
# 2                                        NaN             on_time
# 3                                        NaN             on_time
# 4                                        NaN             on_time
# ...                                      ...                 ...
# 19785712                         Information             on_time
# 19785713                         Information             on_time
# 19785714                         Information             on_time
# 19785715  Information. (Quelle: zuginfo.nrw)             on_time
# 19785716  Information. (Quelle: zuginfo.nrw)             on_time
#
#          departure_delay_check            current_station  stop_number  \
# 0                      on_time  stolberg(rheinl)hbf gl.44            1
# 1                      on_time        eschweiler-st.jöris            2
# 2                      on_time         alsdorf poststraße            3
# 3                      on_time          alsdorf-mariadorf            4
# 4                      on_time        alsdorf-kellersberg            5
# ...                        ...                        ...          ...
# 19785712               on_time                 lübeck hbf            6
# 19785713               on_time               bad oldesloe            1
# 19785714               on_time            reinfeld(holst)            2
# 19785715               on_time                       <NA>            1
# 19785716               on_time                       <NA>            1
#
#                IBNR         Station Name                          ID_Base  \
# 0               NaN                  NaN   1573967790757085557-2407072312
# 1         8001854.0  eschweiler-st.jöris   1573967790757085557-2407072312
# 2         8000047.0   alsdorf poststraße   1573967790757085557-2407072312
# 3         8000049.0    alsdorf-mariadorf   1573967790757085557-2407072312
# 4         8000049.0  alsdorf-kellersberg   1573967790757085557-2407072312
# ...             ...                  ...                              ...
# 19785712  8004905.0           lübeck hbf   3370285438001482281-2407142234
# 19785713  8000218.0         bad oldesloe  -8774053210575864323-2407142305
# 19785714  8007335.0      reinfeld(holst)  -8774053210575864323-2407142305
# 19785715        NaN                  NaN  -1537118689903044118-2407142354
# 19785716        NaN                  NaN   2862161729195150146-2407142324
#
#          ID_Number
# 0               14
# 1               14
# 2               14
# 3               14
# 4               14
# ...            ...
# 19785712         7
# 19785713         3
# 19785714         3
# 19785715         1
# 19785716         1
#
# [19785717 rows x 25 columns]

# %%
# station_external_eva_mapping_v2_df.head(50)

# %%
station_external_eva_mapping_v2_df.count()
# Out:
# ID                       19785717
# line                     19785717
# eva_nr                   19785717
# category                 19785717
# station                  19785717
# state                    19785717
# city                     19785717
# zip                      19785717
# long                     19785717
# lat                      19785717
# arrival_plan             19574362
# departure_plan           19785717
# arrival_change           18020530
# departure_change         18039856
# arrival_delay_m          19785717
# departure_delay_m        19785717
# info                      6933524
# arrival_delay_check      19785717
# departure_delay_check    19785717
# current_station          19574362
# stop_number              19785717
# IBNR                     18475441
# Station Name             18475441
# dtype: int64

# %%
filtered_v2_df.count()
# Out:
# ID                       1098921
# line                     1098921
# eva_nr                   1098921
# category                 1098921
# station                  1098921
# state                    1098921
# city                     1098921
# zip                      1098921
# long                     1098921
# lat                      1098921
# arrival_plan             1098921
# departure_plan           1098921
# arrival_change            983602
# departure_change          963084
# arrival_delay_m          1098921
# departure_delay_m        1098921
# info                      274345
# arrival_delay_check      1098921
# departure_delay_check    1098921
# current_station          1098921
# stop_number              1098921
# Station Name                   0
# IBNR                           0
# dtype: int64

# %%
# Split the ID column into 'ID_Base' and 'ID_Number'
station_external_eva_mapping_v2_df[['ID_Base', 'ID_Number']] = station_external_eva_mapping_v2_df['ID'].str.rsplit('-', n=1, expand=True)

# Convert 'ID_Number' to numeric
station_external_eva_mapping_v2_df['ID_Number'] = pd.to_numeric(station_external_eva_mapping_v2_df['ID_Number'])

# %%
# Get the indices of the rows with the highest 'ID_Number' for each 'ID_Base'
idx_max_id_number = station_external_eva_mapping_v2_df.groupby('ID_Base')['ID_Number'].idxmax()

# %%
# Step 1: Identify all IDs with at least one missing IBNR
ids_with_missing_ibnr = station_external_eva_mapping_v2_df[
    station_external_eva_mapping_v2_df['IBNR'].isna()
]['ID'].unique()

# Step 2: Filter out all rows belonging to those IDs
filtered_routes_df = station_external_eva_mapping_v2_df[
    ~station_external_eva_mapping_v2_df['ID'].isin(ids_with_missing_ibnr)
]

# Get the indices of the rows with the highest 'ID_Number' for each 'ID_Base'
idx_max_id_number = filtered_routes_df.groupby('ID_Base')['ID_Number'].idxmax()

# Use the indices to filter the original DataFrame
filtered_routes_df = filtered_routes_df.loc[idx_max_id_number]
# Out:
#                                          ID  line   eva_nr  category  \
# 38          349781417030375472-2407080017-2    18  8000404         5
# 39         1983158592123451570-2407080010-3    33  8000404         5
# 40         1983158592123451570-2407080010-3    33  8000404         5
# 41        -5293934437045765939-2407080023-2     4  8000404         5
# 42         6845762881043426854-2407072357-6  RB33  8000404         5
# ...                                     ...   ...      ...       ...
# 19785704  -3877986638624297828-2407142237-4    S9  8002795         5
# 19785705  -3877986638624297828-2407142237-4    S9  8002795         5
# 19785706  -3877986638624297828-2407142237-4    S9  8002795         5
# 19785713  -8774053210575864323-2407142305-3    80  8003775         5
# 19785714  -8774053210575864323-2407142305-3    80  8003775         5
#
#                   station                state    city    zip       long  \
# 38            Aachen West  Nordrhein-Westfalen  Aachen  52072   6.070715
# 39            Aachen West  Nordrhein-Westfalen  Aachen  52072   6.070715
# 40            Aachen West  Nordrhein-Westfalen  Aachen  52072   6.070715
# 41            Aachen West  Nordrhein-Westfalen  Aachen  52072   6.070715
# 42            Aachen West  Nordrhein-Westfalen  Aachen  52072   6.070715
# ...                   ...                  ...     ...    ...        ...
# 19785704   Herten (Westf)  Nordrhein-Westfalen  Herten  45699   7.139053
# 19785705   Herten (Westf)  Nordrhein-Westfalen  Herten  45699   7.139053
# 19785706   Herten (Westf)  Nordrhein-Westfalen  Herten  45699   7.139053
# 19785713  Lübeck-Moisling   Schleswig-Holstein  Lübeck  23560  10.629500
# 19785714  Lübeck-Moisling   Schleswig-Holstein  Lübeck  23560  10.629500
#
#                 lat  ...     departure_change arrival_delay_m  \
# 38        50.780360  ...                  NaN               0
# 39        50.780360  ...  2024-07-08 00:21:00               0
# 40        50.780360  ...  2024-07-08 00:21:00               0
# 41        50.780360  ...  2024-07-08 00:31:00               0
# 42        50.780360  ...                  NaN               0
# ...             ...  ...                  ...             ...
# 19785704  51.597508  ...                  NaN               0
# 19785705  51.597508  ...                  NaN               0
# 19785706  51.597508  ...                  NaN               0
# 19785713  53.836800  ...  2024-07-14 23:18:00               0
# 19785714  53.836800  ...  2024-07-14 23:18:00               0
#
#          departure_delay_m                                info  \
# 38                       0                                 NaN
# 39                       0                                 NaN
# 40                       0                                 NaN
# 41                       0  Bauarbeiten. (Quelle: zuginfo.nrw)
# 42                       0                                 NaN
# ...                    ...                                 ...
# 19785704                 0                                 NaN
# 19785705                 0                                 NaN
# 19785706                 0                                 NaN
# 19785713                 0                         Information
# 19785714                 0                         Information
#
#           arrival_delay_check  departure_delay_check  current_station  \
# 38                    on_time                on_time       aachen hbf
# 39                    on_time                on_time     herzogenrath
# 40                    on_time                on_time       kohlscheid
# 41                    on_time                on_time     herzogenrath
# 42                    on_time                on_time          lindern
# ...                       ...                    ...              ...
# 19785704              on_time                on_time      bottrop hbf
# 19785705              on_time                on_time      bottrop-boy
# 19785706              on_time                on_time    gladbeck west
# 19785713              on_time                on_time     bad oldesloe
# 19785714              on_time                on_time  reinfeld(holst)
#
#          stop_number       IBNR     Station Name
# 38                 1  8000001.0       aachen hbf
# 39                 1  8003378.0     herzogenrath
# 40                 2  8004167.0       kohlscheid
# 41                 1  8003378.0     herzogenrath
# 42                 1  8004765.0          lindern
# ...              ...        ...              ...
# 19785704           1  8000746.0      bottrop hbf
# 19785705           2  8000749.0      bottrop-boy
# 19785706           3  8002461.0    gladbeck west
# 19785713           1  8000218.0     bad oldesloe
# 19785714           2  8007335.0  reinfeld(holst)
#
# [11841078 rows x 23 columns]

# %%
# # Step 1: Identify all IDs with at least one missing IBNR
# ids_with_missing_ibnr = station_external_eva_mapping_v2_df[
#     station_external_eva_mapping_v2_df['IBNR'].isna()
# ]['ID'].unique()
#
# # Step 2: Filter out all rows belonging to those IDs
# filtered_routes_df = station_external_eva_mapping_v2_df[
#     ~station_external_eva_mapping_v2_df['ID'].isin(ids_with_missing_ibnr)
# ].copy()  # Use `.copy()` to create an explicit copy
#
# # Split the ID column into 'ID_Base' and 'ID_Number'
# filtered_routes_df[['ID_Base', 'ID_Number']] = filtered_routes_df['ID'].str.rsplit('-', n=1, expand=True)
#
# # Convert 'ID_Number' to numeric for comparison
# filtered_routes_df['ID_Number'] = pd.to_numeric(filtered_routes_df['ID_Number'])
#
# # Sort the DataFrame by 'ID_Base' and 'ID_Number' to ensure correct ordering
# filtered_routes_df = filtered_routes_df.sort_values(by=['ID_Base', 'ID_Number'], ascending=[True, False])
#
# # Get the indices of the rows with the highest 'ID_Number' for each 'ID_Base'
# idx_max_id_number = filtered_routes_df.groupby('ID_Base')['ID_Number'].idxmax()
#
# # Use the indices to filter the original DataFrame
# filtered_routes_df = filtered_routes_df.loc[idx_max_id_number]

# %%
filtered_routes_df.head(1000)
