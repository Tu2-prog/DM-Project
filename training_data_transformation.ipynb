# %%
import pandas as pd

# %%
train_rides_df = pd.read_csv('DBtrainrides.csv')

# %%
# Split the ID column into 'ID_Base' and 'ID_Number'
train_rides_df[['ID_Base', 'ID_Timestamp', 'ID_Stop_Number']] = train_rides_df['ID'].str.rsplit('-', n=2, expand=True)

# Convert 'ID_Number' to numeric
train_rides_df['ID_Stop_Number'] = pd.to_numeric(train_rides_df['ID_Stop_Number'])

# %%
# Rename 'eva_nr' to 'starting_station_IBNR'
train_rides_df = train_rides_df.rename(columns={'eva_nr': 'starting_station_IBNR'})

# Drop starting station string and accompanying data 
train_rides_df.drop(['station', 'state', 'city', 'long', 'lat'], axis=1, inplace=True)

# %%
# TODO: Potentially Drop arrival_delay_m, departure_delay_m, arrival_delay_check, departure_delay_check

# %%
# Remove 'ID' column and reorder columns so 'ID_Base', 'ID_Number', 'ID_Timestamp' are at the start
new_column_order = ['ID_Base', 'ID_Timestamp', 'ID_Stop_Number'] + [col for col in train_rides_df.columns if
                                                                    col not in ['ID', 'ID_Base',
                                                                                'ID_Timestamp', 'ID_Stop_Number',
                                                                                ]
                                                                    ]
train_rides_df = train_rides_df.drop(columns=['ID'])
train_rides_df = train_rides_df[new_column_order]

# %%
# Display the first few rows of the train rides DataFrame
train_rides_df.head()
# Out:
#                ID_Base ID_Timestamp  ID_Stop_Number line  \
# 0  1573967790757085557   2407072312              14   20
# 1   349781417030375472   2407080017               1   18
# 2  7157250219775883918   2407072120              25    1
# 3   349781417030375472   2407080017               2   18
# 4  1983158592123451570   2407080010               3   33
#
#                                                 path  starting_station_IBNR  \
# 0  Stolberg(Rheinl)Hbf Gl.44|Eschweiler-St.Jöris|...                8000001
# 1                                                NaN                8000001
# 2  Hamm(Westf)Hbf|Kamen|Kamen-Methler|Dortmund-Ku...                8000406
# 3                                         Aachen Hbf                8000404
# 4                            Herzogenrath|Kohlscheid                8000404
#
#    category    zip         arrival_plan       departure_plan  \
# 0         2  52064  2024-07-08 00:00:00  2024-07-08 00:01:00
# 1         2  52064                  NaN  2024-07-08 00:17:00
# 2         4  52066  2024-07-08 00:03:00  2024-07-08 00:04:00
# 3         5  52072  2024-07-08 00:20:00  2024-07-08 00:21:00
# 4         5  52072  2024-07-08 00:20:00  2024-07-08 00:21:00
#
#         arrival_change     departure_change  arrival_delay_m  \
# 0  2024-07-08 00:03:00  2024-07-08 00:04:00                3
# 1                  NaN                  NaN                0
# 2  2024-07-08 00:03:00  2024-07-08 00:04:00                0
# 3                  NaN                  NaN                0
# 4  2024-07-08 00:20:00  2024-07-08 00:21:00                0
#
#    departure_delay_m info arrival_delay_check departure_delay_check
# 0                  3  NaN             on_time               on_time
# 1                  0  NaN             on_time               on_time
# 2                  0  NaN             on_time               on_time
# 3                  0  NaN             on_time               on_time
# 4                  0  NaN             on_time               on_time

# %%
# Count missing values to understand data quality
train_rides_df.count()
# Out:
# ID_Base                  2061357
# ID_Timestamp             2061357
# ID_Stop_Number           2061357
# line                     2061357
# path                     1850002
# starting_station_IBNR    2061357
# category                 2061357
# zip                      2061357
# arrival_plan             1850002
# departure_plan           2061357
# arrival_change           1585727
# departure_change         1721431
# arrival_delay_m          2061357
# departure_delay_m        2061357
# info                      645341
# arrival_delay_check      2061357
# departure_delay_check    2061357
# dtype: int64

# %%
# Group by 'zip' to understand distribution
zip_df = train_rides_df.groupby('zip').size().reset_index(name='count')
zip_df
# Out:
#         zip  count
# 0      1067   2458
# 1      1069   2045
# 2      1097   3305
# 3      1109   1800
# 4      1127    597
# ...     ...    ...
# 1646  99817    453
# 1647  99867    494
# 1648  99880    424
# 1649  99947    453
# 1650  99974    421
#
# [1651 rows x 2 columns]

# %% [markdown]
# ### Station Mapping
# We create a mapping of stations to understand how often each 'eva_nr' appears in the dataset.

# %%
# Step 2: Create a new DataFrame with a count of how often each 'eva_nr' is mentioned
station_mapping_df = train_rides_df['starting_station_IBNR'].value_counts().reset_index()
station_mapping_df.columns = ['starting_station_IBNR', 'count']
station_mapping_df
# Out:
#       starting_station_IBNR  count
# 0                   8004128   8732
# 1                   8089047   8312
# 2                   8000262   7814
# 3                   8004132   7598
# 4                   8004131   7382
# ...                     ...    ...
# 1991                8007768     95
# 1992                8005644     74
# 1993                8005543     49
# 1994                8010035      5
# 1995                8010241      5
#
# [1996 rows x 2 columns]

# %%
# Count number of unique 'eva_nr' to understand the spread across different stations
station_mapping_df.count()
# Out:
# starting_station_IBNR    1996
# count                    1996
# dtype: int64

# %%
# Fill missing values in 'path' with empty strings
train_rides_df['path'] = train_rides_df['path'].fillna('')

# Split the 'path' into individual stations by '|', creating a list in each row
train_rides_df = train_rides_df.assign(current_station=train_rides_df['path'].str.split('|'))

# Explode the 'current_station' column to create individual rows for each station
split_stations_df = train_rides_df.explode('current_station').drop(columns=['path'])

# Add a counter to keep track of the sequence of stops within each path
split_stations_df['stop_number'] = split_stations_df.groupby(
    ['ID_Base', 'ID_Timestamp', 'ID_Stop_Number']).cumcount() + 1

# Display the result
split_stations_df.head()
# Out:
#                ID_Base ID_Timestamp  ID_Stop_Number line  \
# 0  1573967790757085557   2407072312              14   20
# 0  1573967790757085557   2407072312              14   20
# 0  1573967790757085557   2407072312              14   20
# 0  1573967790757085557   2407072312              14   20
# 0  1573967790757085557   2407072312              14   20
#
#    starting_station_IBNR  category    zip         arrival_plan  \
# 0                8000001         2  52064  2024-07-08 00:00:00
# 0                8000001         2  52064  2024-07-08 00:00:00
# 0                8000001         2  52064  2024-07-08 00:00:00
# 0                8000001         2  52064  2024-07-08 00:00:00
# 0                8000001         2  52064  2024-07-08 00:00:00
#
#         departure_plan       arrival_change     departure_change  \
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
#
#    arrival_delay_m  departure_delay_m info arrival_delay_check  \
# 0                3                  3  NaN             on_time
# 0                3                  3  NaN             on_time
# 0                3                  3  NaN             on_time
# 0                3                  3  NaN             on_time
# 0                3                  3  NaN             on_time
#
#   departure_delay_check            current_station  stop_number
# 0               on_time  Stolberg(Rheinl)Hbf Gl.44            1
# 0               on_time        Eschweiler-St.Jöris            2
# 0               on_time         Alsdorf Poststraße            3
# 0               on_time          Alsdorf-Mariadorf            4
# 0               on_time        Alsdorf-Kellersberg            5

# %%
ibnr_index_df = pd.read_csv('ibnr_stations_index.csv')

# %%
# Remove any leading or trailing spaces and set to lower case letters
split_stations_df['current_station'] = split_stations_df['current_station'].str.strip().str.lower()
ibnr_index_df['Station Name'] = ibnr_index_df['Station Name'].str.strip().str.lower()

# %%
ibnr_index_df
# Out:
#          IBNR         Station Name
# 0     8000001           aachen hbf
# 1     8000001                   ac
# 2     8000001               aken c
# 3     8000001           aquisgrana
# 4     8000001      aix-la-chapelle
# ...       ...                  ...
# 9128  8098553    hamburg-altona(s)
# 9129  8098555        bensersiel ne
# 9130  8099503       hildesheim gbf
# 9131  8099506  stolberg(rheinl)gbf
# 9132  8099507   neustadt(holst)gbf
#
# [9133 rows x 2 columns]

# %%
# Updated merge using 'station' instead of 'Station Name'
split_station_with_ibnr_df = split_stations_df.merge(
    ibnr_index_df,
    how='left',
    left_on='current_station',
    right_on='Station Name'
)

# %%
split_station_with_ibnr_df.head(10)
# Out:
#                ID_Base ID_Timestamp  ID_Stop_Number line  \
# 0  1573967790757085557   2407072312              14   20
# 1  1573967790757085557   2407072312              14   20
# 2  1573967790757085557   2407072312              14   20
# 3  1573967790757085557   2407072312              14   20
# 4  1573967790757085557   2407072312              14   20
# 5  1573967790757085557   2407072312              14   20
# 6  1573967790757085557   2407072312              14   20
# 7  1573967790757085557   2407072312              14   20
# 8  1573967790757085557   2407072312              14   20
# 9  1573967790757085557   2407072312              14   20
#
#    starting_station_IBNR  category    zip         arrival_plan  \
# 0                8000001         2  52064  2024-07-08 00:00:00
# 1                8000001         2  52064  2024-07-08 00:00:00
# 2                8000001         2  52064  2024-07-08 00:00:00
# 3                8000001         2  52064  2024-07-08 00:00:00
# 4                8000001         2  52064  2024-07-08 00:00:00
# 5                8000001         2  52064  2024-07-08 00:00:00
# 6                8000001         2  52064  2024-07-08 00:00:00
# 7                8000001         2  52064  2024-07-08 00:00:00
# 8                8000001         2  52064  2024-07-08 00:00:00
# 9                8000001         2  52064  2024-07-08 00:00:00
#
#         departure_plan       arrival_change     departure_change  \
# 0  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 1  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 2  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 3  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 4  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 5  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 6  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 7  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 8  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 9  2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
#
#    arrival_delay_m  departure_delay_m info arrival_delay_check  \
# 0                3                  3  NaN             on_time
# 1                3                  3  NaN             on_time
# 2                3                  3  NaN             on_time
# 3                3                  3  NaN             on_time
# 4                3                  3  NaN             on_time
# 5                3                  3  NaN             on_time
# 6                3                  3  NaN             on_time
# 7                3                  3  NaN             on_time
# 8                3                  3  NaN             on_time
# 9                3                  3  NaN             on_time
#
#   departure_delay_check                    current_station  stop_number  \
# 0               on_time          stolberg(rheinl)hbf gl.44            1
# 1               on_time                eschweiler-st.jöris            2
# 2               on_time                 alsdorf poststraße            3
# 3               on_time                  alsdorf-mariadorf            4
# 4               on_time                alsdorf-kellersberg            5
# 5               on_time                   alsdorf-annapark            6
# 6               on_time                      alsdorf-busch            7
# 7               on_time  herzogenrath-august-schmidt-platz            8
# 8               on_time         herzogenrath-alt-merkstein            9
# 9               on_time                       herzogenrath           10
#
#         IBNR                       Station Name
# 0        NaN                                NaN
# 1  8001917.0                eschweiler-st.jöris
# 2  8000510.0                 alsdorf poststraße
# 3  8000527.0                  alsdorf-mariadorf
# 4  8000521.0                alsdorf-kellersberg
# 5  8000502.0                   alsdorf-annapark
# 6  8000507.0                      alsdorf-busch
# 7  8002816.0  herzogenrath-august-schmidt-platz
# 8  8002804.0         herzogenrath-alt-merkstein
# 9  8002806.0                       herzogenrath

# %%
split_station_with_ibnr_df.columns
# Out:
# Index(['ID_Base', 'ID_Timestamp', 'ID_Stop_Number', 'line',
#        'starting_station_IBNR', 'category', 'zip', 'arrival_plan',
#        'departure_plan', 'arrival_change', 'departure_change',
#        'arrival_delay_m', 'departure_delay_m', 'info', 'arrival_delay_check',
#        'departure_delay_check', 'current_station', 'stop_number', 'IBNR',
#        'Station Name'],
#       dtype='object')

# %%
split_station_with_ibnr_df.count()
# Out:
# ID_Base                  19714107
# ID_Timestamp             19714107
# ID_Stop_Number           19714107
# line                     19714107
# starting_station_IBNR    19714107
# category                 19714107
# zip                      19714107
# arrival_plan             19502752
# departure_plan           19714107
# arrival_change           17953196
# departure_change         17972570
# arrival_delay_m          19714107
# departure_delay_m        19714107
# info                      6886047
# arrival_delay_check      19714107
# departure_delay_check    19714107
# current_station          19714107
# stop_number              19714107
# IBNR                     18584536
# Station Name             18584536
# dtype: int64

# %%
# Convert empty strings back to NaN in 'path' column
split_station_with_ibnr_df['current_station'] = split_station_with_ibnr_df['current_station'].replace('',
                                                                                                      pd.NA)

# %%
# Count rows where 'current_station' is NaN
nan_station_count = split_station_with_ibnr_df['current_station'].isna().sum()
print(f"Number of rows with NaN station names: {nan_station_count}")
# Out:
# Number of rows with NaN station names: 211355

# %%
# Count where 'Station Name' is NaN and 'current_station' is not NaN
count_nan_station_name = split_station_with_ibnr_df[
    (split_station_with_ibnr_df['Station Name'].isna()) &
    (split_station_with_ibnr_df['current_station'].notna())
    ].shape[0]
print(f"Number of rows with NaN IBNR that have a current station: {count_nan_station_name}")
# Out:
# Number of rows with NaN IBNR that have a current station: 918216

# %%
# Count rows where 'Station Name' is NaN
nan_station_count = split_station_with_ibnr_df['Station Name'].isna().sum()
print(f"Number of rows with NaN station names: {nan_station_count}")
# Out:
# Number of rows with NaN station names: 1129571

# %%
split_station_with_no_ibnr_df = split_station_with_ibnr_df[split_station_with_ibnr_df['Station Name'].isna()]
split_station_with_no_ibnr_df.head(10)
# Out:
#                  ID_Base ID_Timestamp  ID_Stop_Number line  \
# 0    1573967790757085557   2407072312              14   20
# 13    349781417030375472   2407080017               1   18
# 14   7157250219775883918   2407072120              25    1
# 47  -2100556839975301087   2407072307              13   18
# 48  -2100556839975301087   2407072307              13   18
# 49  -2100556839975301087   2407072307              13   18
# 50  -2100556839975301087   2407072307              13   18
# 51  -2100556839975301087   2407072307              13   18
# 52  -2100556839975301087   2407072307              13   18
# 53  -2100556839975301087   2407072307              13   18
#
#     starting_station_IBNR  category    zip         arrival_plan  \
# 0                 8000001         2  52064  2024-07-08 00:00:00
# 13                8000001         2  52064                  NaN
# 14                8000406         4  52066  2024-07-08 00:03:00
# 47                8000404         5  52072  2024-07-08 00:37:00
# 48                8000404         5  52072  2024-07-08 00:37:00
# 49                8000404         5  52072  2024-07-08 00:37:00
# 50                8000404         5  52072  2024-07-08 00:37:00
# 51                8000404         5  52072  2024-07-08 00:37:00
# 52                8000404         5  52072  2024-07-08 00:37:00
# 53                8000404         5  52072  2024-07-08 00:37:00
#
#          departure_plan       arrival_change     departure_change  \
# 0   2024-07-08 00:01:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 13  2024-07-08 00:17:00                  NaN                  NaN
# 14  2024-07-08 00:04:00  2024-07-08 00:03:00  2024-07-08 00:04:00
# 47  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 48  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 49  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 50  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 51  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 52  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
# 53  2024-07-08 00:41:00  2024-07-08 00:37:00  2024-07-08 00:41:00
#
#     arrival_delay_m  departure_delay_m info arrival_delay_check  \
# 0                 3                  3  NaN             on_time
# 13                0                  0  NaN             on_time
# 14                0                  0  NaN             on_time
# 47                0                  0  NaN             on_time
# 48                0                  0  NaN             on_time
# 49                0                  0  NaN             on_time
# 50                0                  0  NaN             on_time
# 51                0                  0  NaN             on_time
# 52                0                  0  NaN             on_time
# 53                0                  0  NaN             on_time
#
#    departure_delay_check            current_station  stop_number  IBNR  \
# 0                on_time  stolberg(rheinl)hbf gl.44            1   NaN
# 13               on_time                       <NA>            1   NaN
# 14               on_time             hamm(westf)hbf            1   NaN
# 47               on_time           liège-guillemins            1   NaN
# 48               on_time                   bressoux            2   NaN
# 49               on_time                       vise            3   NaN
# 50               on_time                    eijsden            4   NaN
# 51               on_time        maastricht randwyck            5   NaN
# 52               on_time                 maastricht            6   NaN
# 53               on_time                   meerssen            7   NaN
#
#    Station Name
# 0           NaN
# 13          NaN
# 14          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN

# %%
# TODO Find the latest version of the routes and remove all older versions
